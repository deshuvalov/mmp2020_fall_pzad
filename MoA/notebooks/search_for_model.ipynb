# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.metrics import log_loss
from tqdm.notebook import tqdm

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

import random
import os
import sys
from pathlib import Path
sys.path.append('../input/iterative-stratification/iterative-stratification-master')
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings('ignore')

#used net arch from kaggle.com/nicohrubec/pytorch-multilabel-neural-network/

# %%
import numpy as np
from joblib import Parallel, delayed
from scipy.interpolate import interp1d
from scipy.special import erf, erfinv
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.utils.validation import FLOAT_DTYPES, check_array, check_is_fitted


class GaussRankScaler(BaseEstimator, TransformerMixin):
    """Transform features by scaling each feature to a normal distribution.
    Parameters
        ----------
        epsilon : float, optional, default 1e-4
            A small amount added to the lower bound or subtracted
            from the upper bound. This value prevents infinite number
            from occurring when applying the inverse error function.
        copy : boolean, optional, default True
            If False, try to avoid a copy and do inplace scaling instead.
            This is not guaranteed to always work inplace; e.g. if the data is
            not a NumPy array, a copy may still be returned.
        n_jobs : int or None, optional, default None
            Number of jobs to run in parallel.
            ``None`` means 1 and ``-1`` means using all processors.
        interp_kind : str or int, optional, default 'linear'
           Specifies the kind of interpolation as a string
            ('linear', 'nearest', 'zero', 'slinear', 'quadratic', 'cubic',
            'previous', 'next', where 'zero', 'slinear', 'quadratic' and 'cubic'
            refer to a spline interpolation of zeroth, first, second or third
            order; 'previous' and 'next' simply return the previous or next value
            of the point) or as an integer specifying the order of the spline
            interpolator to use.
        interp_copy : bool, optional, default False
            If True, the interpolation function makes internal copies of x and y.
            If False, references to `x` and `y` are used.
        Attributes
        ----------
        interp_func_ : list
            The interpolation function for each feature in the training set.
        """

    def __init__(self, epsilon=1e-4, copy=True, n_jobs=None, interp_kind='linear', interp_copy=False):
        self.epsilon = epsilon
        self.copy = copy
        self.interp_kind = interp_kind
        self.interp_copy = interp_copy
        self.fill_value = 'extrapolate'
        self.n_jobs = n_jobs

    def fit(self, X, y=None):
        """Fit interpolation function to link rank with original data for future scaling
        Parameters
        ----------
        X : array-like, shape (n_samples, n_features)
            The data used to fit interpolation function for later scaling along the features axis.
        y
            Ignored
        """
        X = check_array(X, copy=self.copy, estimator=self, dtype=FLOAT_DTYPES, force_all_finite=True)

        self.interp_func_ = Parallel(n_jobs=self.n_jobs)(delayed(self._fit)(x) for x in X.T)
        return self

    def _fit(self, x):
        x = self.drop_duplicates(x)
        rank = np.argsort(np.argsort(x))
        bound = 1.0 - self.epsilon
        factor = np.max(rank) / 2.0 * bound
        scaled_rank = np.clip(rank / factor - bound, -bound, bound)
        return interp1d(
            x, scaled_rank, kind=self.interp_kind, copy=self.interp_copy, fill_value=self.fill_value)

    def transform(self, X, copy=None):
        """Scale the data with the Gauss Rank algorithm
        Parameters
        ----------
        X : array-like, shape (n_samples, n_features)
            The data used to scale along the features axis.
        copy : bool, optional (default: None)
            Copy the input X or not.
        """
        check_is_fitted(self, 'interp_func_')

        copy = copy if copy is not None else self.copy
        X = check_array(X, copy=copy, estimator=self, dtype=FLOAT_DTYPES, force_all_finite=True)

        X = np.array(Parallel(n_jobs=self.n_jobs)(delayed(self._transform)(i, x) for i, x in enumerate(X.T))).T
        return X

    def _transform(self, i, x):
        return erfinv(self.interp_func_[i](x))

    def inverse_transform(self, X, copy=None):
        """Scale back the data to the original representation
        Parameters
        ----------
        X : array-like, shape [n_samples, n_features]
            The data used to scale along the features axis.
        copy : bool, optional (default: None)
            Copy the input X or not.
        """
        check_is_fitted(self, 'interp_func_')

        copy = copy if copy is not None else self.copy
        X = check_array(X, copy=copy, estimator=self, dtype=FLOAT_DTYPES, force_all_finite=True)

        X = np.array(Parallel(n_jobs=self.n_jobs)(delayed(self._inverse_transform)(i, x) for i, x in enumerate(X.T))).T
        return X

    def _inverse_transform(self, i, x):
        inv_interp_func = interp1d(self.interp_func_[i].y, self.interp_func_[i].x, kind=self.interp_kind,
                                   copy=self.interp_copy, fill_value=self.fill_value)
        return inv_interp_func(erf(x))

    @staticmethod
    def drop_duplicates(x):
        is_unique = np.zeros_like(x, dtype=bool)
        is_unique[np.unique(x, return_index=True)[1]] = True
        return x[is_unique]

# %% [markdown]
# submit[targets] = preds
# submit.loc[X_test['cp_type']=='ctl_vehicle', targets] = 0
# submit.to_csv('submission.csv', index=False)

# %%
import ctypes
ctypes.cdll.LoadLibrary('caffe2_nvrtc.dll')
# Out:
# <CDLL 'caffe2_nvrtc.dll', handle 7ffae3170000 at 0x285220915e0>

# %%
seed = 42

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
set_seed(seed)

# %%
p_min = 1e-15
p_max = 1 - p_min

def score(y_true, y_pred):
    y_true = np.asarray(y_true)
    y_pred = np.asarray(y_pred)
    y_pred = np.clip(y_pred, p_min, p_max)
    return -(y_true * np.log(y_pred) + (1 - y_true) * np.log(1 - y_pred)).mean()

# %%
train_X = pd.read_csv('../input/lish-moa/train_features.csv', index_col='sig_id')
test_Y = pd.read_csv('../input/lish-moa/sample_submission.csv', index_col='sig_id')
train_Y = pd.read_csv('../input/lish-moa/train_targets_scored.csv', index_col='sig_id', dtype={f: test_Y.dtypes[f] for f in test_Y})
test_X = pd.read_csv('../input/lish-moa/test_features.csv', index_col='sig_id')

# %%
train_X.cp_time = train_X.cp_time / 24
test_X.cp_time = test_X.cp_time / 24

train_X['real_drug'] = train_X.cp_type == 'trt_cp'
test_X['real_drug'] = test_X.cp_type == 'trt_cp'

t = train_X.cp_dose.copy()
train_X.drop(columns=['cp_dose', 'cp_type'], inplace=True)
train_X['cp_dose'] = 1
train_X.loc[(t == 'D2'), 'cp_dose'] = 2

t = test_X.cp_dose.copy()
test_X.drop(columns=['cp_dose', 'cp_type'], inplace=True)
test_X['cp_dose'] = 1
test_X.loc[(t == 'D2'), 'cp_dose'] = 2

# %%
nfolds = 6
nstarts = 1
nepochs = 50
batch_size = 128
val_batch_size = batch_size * 4
criterion = nn.BCELoss()
kfold = MultilabelStratifiedKFold(n_splits=nfolds, random_state=517, shuffle=True)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class Dataset_my(Dataset):
    def __init__(self, df, targets, mode='train'):
        self.mode = mode
        #self.feats = feats_idx
        #self.data = df[:, feats_idx]
        self.data = df
        if mode=='train':
            self.targets = targets
    
    def __getitem__(self, idx):
        if self.mode == 'train':
            return torch.FloatTensor(self.data[idx]), torch.FloatTensor(self.targets[idx])
        elif self.mode == 'test':
            return torch.FloatTensor(self.data[idx]), 0
        
    def __len__(self):
        return len(self.data)

# %%
def run_CV_for_model(cur_model, model_num, train_X_loc, train_Y_loc, test_X_loc):
    set_seed(seed)
    for n, (tr, te) in enumerate(kfold.split(train_Y_loc, train_Y_loc)):
        print(f'Train fold {n+1}')
        xtrain, xval = train_X_loc[tr], train_X_loc[te]
        ytrain, yval = train_Y_loc[tr], train_Y_loc[te]

        train_set = Dataset_my(xtrain, ytrain)
        val_set = Dataset_my(xval, yval)

        dataloaders = {
            'train': DataLoader(train_set, batch_size=batch_size, shuffle=True),
            'val': DataLoader(val_set, batch_size=val_batch_size, shuffle=False)
        }

        model = cur_model(train_X_loc.shape[1]).to(device)
        Path(f'./saved_params/model{model_num}').mkdir(parents=True, exist_ok=True)
        checkpoint_path = f'./saved_params/model{model_num}/repeat_{1}_Fold_{n+1}.pt'
        optimizer = optim.Adam(model.parameters(), weight_decay=1e-5)
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3, eps=1e-4, verbose=True)
        best_loss = {'train': np.inf, 'val': np.inf}

        for epoch in range(nepochs):
            epoch_loss = {'train': 0.0, 'val': 0.0}

            for phase in ['train', 'val']:
                if phase == 'train':
                    model.train()
                else:
                    model.eval()

                running_loss = 0.0

                for i, (x, y) in enumerate(dataloaders[phase]):
                    x, y = x.to(device), y.to(device)

                    optimizer.zero_grad()

                    with torch.set_grad_enabled(phase=='train'):
                        preds = model(x)
                        loss = criterion(preds, y)

                        if phase=='train':
                            loss.backward()
                            optimizer.step()

                    running_loss += loss.item() / len(dataloaders[phase])

                epoch_loss[phase] = running_loss

            print("Epoch {}/{}   -   loss: {:5.5f}   -   val_loss: {:5.5f}".format(epoch+1, nepochs, epoch_loss['train'], epoch_loss['val']))

            scheduler.step(epoch_loss['val'])

            if epoch_loss['val'] < best_loss['val']:
                best_loss = epoch_loss
                torch.save(model.state_dict(), checkpoint_path)
    return best_loss

# %%
def train_model(cur_model, model_num, train_X_loc, train_Y_loc):
    set_seed(seed)
    train_set = Dataset_my(train_X_loc, train_Y_loc)

    dataloaders = {
        'train': DataLoader(train_set, batch_size=batch_size, shuffle=True)
    }

    model = cur_model(train_X_loc.shape[1]).to(device)
    Path(f'./saved_params/model{model_num}').mkdir(parents=True, exist_ok=True)
    checkpoint_path = f'./saved_params/model{model_num}/repeat_{1}_Fold_{n+1}.pt'
    optimizer = optim.Adam(model.parameters(), weight_decay=1e-5)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=3, eps=1e-4, verbose=True)
    best_loss = {'train': np.inf}

    for epoch in range(nepochs):
        epoch_loss = {'train': 0.0}

        for phase in ['train']:
            if phase == 'train':
                model.train()

            for i, (x, y) in enumerate(dataloaders[phase]):
                x, y = x.to(device), y.to(device)

                optimizer.zero_grad()

                with torch.set_grad_enabled(phase=='train'):
                    preds = model(x)
                    loss = criterion(preds, y)

                    if phase=='train':
                        loss.backward()
                        optimizer.step()

        scheduler.step(epoch_loss['train'])

        if epoch_loss['train'] < best_loss['train']:
            best_loss = epoch_loss
            torch.save(model.state_dict(), checkpoint_path)

# %%
def predict_model(cur_model, model_num, test_X_loc):
    set_seed(seed)
    train_set = Dataset_my(test_X_loc, None, mode='test')

    dataloaders = {
        'test': DataLoader(train_set, batch_size=val_batch_size, shuffle=False)
    }

    model = cur_model(test_X_loc.shape[1]).to(device)
    checkpoint_path = f'./saved_params/model{model_num}/repeat_{1}_Fold_{n+1}.pt'
    model.load_state_dict(torch.load(checkpoint_path))
    model.eval()
    
    fold_preds = []

    for i, (x, y) in enumerate(dataloaders[phase]):
        x, y = x.to(device), y.to(device)

        optimizer.zero_grad()

        with torch.no_grad():
            batch_preds = model(x)
            fold_preds.append(batch_preds)

    fold_preds = torch.cat(fold_preds, dim=0).cpu().numpy()
    fold_preds[train_X.real_drug == False] = 0
    print(fold_preds.shape)

# %%
def run_eval_for_model(cur_model, model_num, train_X_loc, train_Y_loc, test_X_loc):
    set_seed(seed)
    oof = np.zeros((len(train_X_loc), nstarts, train_Y_loc.shape[1]))
    oof_targets = np.zeros((len(train_X_loc), train_Y_loc.shape[1]))
    preds = np.zeros((len(test_X_loc), train_Y_loc.shape[1]))
    seed_targets = []
    seed_oof = []
    seed_preds = np.zeros((len(test_X_loc), train_Y_loc.shape[1], nfolds))

    for n, (tr, te) in enumerate(kfold.split(train_Y_loc, train_Y_loc)):
        xval, yval = train_X_loc[te], train_Y_loc[te]
        fold_preds = []

        val_set = Dataset_my(xval, yval)
        test_set = Dataset_my(test_X_loc, None, mode='test')

        dataloaders = {
            'val': DataLoader(val_set, batch_size=val_batch_size, shuffle=False),
            'test': DataLoader(test_set, batch_size=val_batch_size, shuffle=False)
        }

        checkpoint_path = f'./saved_params/model{model_num}/repeat_{1}_Fold_{n+1}.pt'
        model = cur_model(train_X_loc.shape[1]).to(device)
        model.load_state_dict(torch.load(checkpoint_path))
        model.eval()

        for phase in ['val', 'test']:
            for i, (x, y) in enumerate(dataloaders[phase]):
                if phase == 'val':
                    x, y = x.to(device), y.to(device)
                elif phase == 'test':
                    x = x.to(device)

                with torch.no_grad():
                    batch_preds = model(x)

                    if phase == 'val':
                        seed_targets.append(y)
                        seed_oof.append(batch_preds)
                    elif phase == 'test':
                        fold_preds.append(batch_preds)

        fold_preds = torch.cat(fold_preds, dim=0).cpu().numpy()
        seed_preds[:, :, n] = fold_preds

    seed_targets = torch.cat(seed_targets, dim=0).cpu().numpy()
    seed_oof = torch.cat(seed_oof, dim=0).cpu().numpy()
    seed_preds = np.mean(seed_preds, axis=2)

    oof_targets = seed_targets
    oof[:, 0, :] = seed_oof
    preds += seed_preds / nstarts

    oof = np.mean(oof, axis=1)
    oof_real = np.zeros(train_Y.shape)
    oof_real[:train_X.real_drug.sum(), :] = oof
    oof_targets_real = np.zeros(train_Y.shape)
    oof_targets_real[:train_X.real_drug.sum(), :] = oof_targets
    print("Overall score is {:5.5f}".format(score(oof_targets_real, oof_real)))

# %%
def run_eval_for_model_true(cur_model, model_num, train_X_loc, train_Y_loc, test_X_loc):
    set_seed(seed + 1)
    oof = np.zeros((len(train_X_loc), nstarts, train_Y_loc.shape[1]))
    oof_targets = np.zeros((len(train_X_loc), train_Y_loc.shape[1]))
    preds = np.zeros((len(test_X_loc), train_Y_loc.shape[1]))
    seed_targets = []
    seed_oof = []
    seed_preds = np.zeros((len(test_X_loc), train_Y_loc.shape[1], nfolds))

    for n, (tr, te) in enumerate(kfold.split(train_Y_loc, train_Y_loc)):
        xval, yval = train_X_loc[te], train_Y_loc[te]
        fold_preds = []

        val_set = Dataset_my(xval, yval)
        test_set = Dataset_my(test_X_loc, None, mode='test')

        dataloaders = {
            'val': DataLoader(val_set, batch_size=val_batch_size, shuffle=False),
            'test': DataLoader(test_set, batch_size=val_batch_size, shuffle=False)
        }

        checkpoint_path = f'./saved_params/model{model_num}/repeat_{1}_Fold_{n+1}.pt'
        model = cur_model(train_X_loc.shape[1]).to(device)
        model.load_state_dict(torch.load(checkpoint_path))
        model.eval()

        for phase in ['val', 'test']:
            for i, (x, y) in enumerate(dataloaders[phase]):
                if phase == 'val':
                    x, y = x.to(device), y.to(device)
                elif phase == 'test':
                    x = x.to(device)

                with torch.no_grad():
                    batch_preds = model(x)

                    if phase == 'val':
                        seed_targets.append(y)
                        seed_oof.append(batch_preds)
                    elif phase == 'test':
                        fold_preds.append(batch_preds)

        fold_preds = torch.cat(fold_preds, dim=0).cpu().numpy()
        seed_preds[:, :, n] = fold_preds

    seed_targets = torch.cat(seed_targets, dim=0).cpu().numpy()
    seed_oof = torch.cat(seed_oof, dim=0).cpu().numpy()
    seed_preds = np.mean(seed_preds, axis=2)

    oof_targets = seed_targets
    oof[:, 0, :] = seed_oof
    preds += seed_preds / nstarts

    oof = np.mean(oof, axis=1)
    oof_real = np.zeros(train_Y.shape)
    oof_real[:train_X.real_drug.sum(), :] = oof
    oof_targets_real = np.zeros(train_Y.shape)
    oof_targets_real[:train_X.real_drug.sum(), :] = oof_targets
    print("Overall score is {:5.5f}".format(score(oof_targets_real, oof_real)))

# %%
class Model0(nn.Module):
    def __init__(self, num_columns):
        super(Model0, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_columns)
        self.dropout1 = nn.Dropout(0.2)
        self.dense1 = nn.utils.weight_norm(nn.Linear(num_columns, 2048))
        
        self.batch_norm2 = nn.BatchNorm1d(2048)
        self.dropout2 = nn.Dropout(0.5)
        self.dense2 = nn.utils.weight_norm(nn.Linear(2048, 1024))
        
        self.batch_norm3 = nn.BatchNorm1d(1024)
        self.dropout3 = nn.Dropout(0.5)
        self.dense3 = nn.utils.weight_norm(nn.Linear(1024, 206))
    
    def forward(self, x):
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        x = F.relu(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = F.relu(self.dense2(x))
        
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x = F.sigmoid(self.dense3(x))
        
        return x

# %%
train_Y0 = train_Y.loc[train_X['real_drug']==True].reset_index(drop=True)
train_X0 = train_X.loc[train_X['real_drug']==True].drop(columns=['real_drug']).reset_index(drop=True)
test_X0 = test_X.drop(columns=['real_drug'])

features = list(train_X0.columns)
nfeatures = len(features)
features_g = [col for col in train_X0.columns if 'g-' in col]
features_c = [col for col in train_X0.columns if 'c-' in col]
features_gc = features_g + features_c
targets = list(train_Y0.columns)
ntargets = len(targets)

train_Y0 = train_Y0.values
train_X0 = train_X0.values
test_X0 = test_X0.values

# %%
run_CV_for_model(Model0, 0, train_X0, train_Y0, test_X0)
# Out:
# Train fold 1
# Epoch 1/50   -   loss: 0.38006   -   val_loss: 0.06840
# Epoch 2/50   -   loss: 0.04316   -   val_loss: 0.02734
# Epoch 3/50   -   loss: 0.02591   -   val_loss: 0.02280
# Epoch 4/50   -   loss: 0.02208   -   val_loss: 0.02049
# Epoch 5/50   -   loss: 0.02076   -   val_loss: 0.01965
# Epoch 6/50   -   loss: 0.01947   -   val_loss: 0.01915
# Epoch 7/50   -   loss: 0.01917   -   val_loss: 0.01879
# Epoch 8/50   -   loss: 0.01834   -   val_loss: 0.01831
# Epoch 9/50   -   loss: 0.01795   -   val_loss: 0.01786
# Epoch 10/50   -   loss: 0.01795   -   val_loss: 0.01772
# Epoch 11/50   -   loss: 0.01732   -   val_loss: 0.01754
# Epoch 12/50   -   loss: 0.01713   -   val_loss: 0.01740
# Epoch 13/50   -   loss: 0.01667   -   val_loss: 0.01722
# Epoch 14/50   -   loss: 0.01635   -   val_loss: 0.01707
# Epoch 15/50   -   loss: 0.01613   -   val_loss: 0.01724
# Epoch 16/50   -   loss: 0.01595   -   val_loss: 0.01728
# Epoch 17/50   -   loss: 0.01579   -   val_loss: 0.01690
# Epoch 18/50   -   loss: 0.01559   -   val_loss: 0.01677
# Epoch 19/50   -   loss: 0.01538   -   val_loss: 0.01676
# Epoch 20/50   -   loss: 0.01518   -   val_loss: 0.01677
# Epoch 21/50   -   loss: 0.01494   -   val_loss: 0.01669
# Epoch 22/50   -   loss: 0.01487   -   val_loss: 0.01674
# Epoch 23/50   -   loss: 0.01471   -   val_loss: 0.01673
# Epoch 24/50   -   loss: 0.01468   -   val_loss: 0.01670
# Epoch 25/50   -   loss: 0.01456   -   val_loss: 0.01679
# Epoch    25: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 26/50   -   loss: 0.01361   -   val_loss: 0.01652
# Epoch 27/50   -   loss: 0.01320   -   val_loss: 0.01646
# Epoch 28/50   -   loss: 0.01293   -   val_loss: 0.01644
# Epoch 29/50   -   loss: 0.01272   -   val_loss: 0.01643
# Epoch 30/50   -   loss: 0.01257   -   val_loss: 0.01639
# Epoch 31/50   -   loss: 0.01232   -   val_loss: 0.01637
# Epoch 32/50   -   loss: 0.01211   -   val_loss: 0.01642
# Epoch 33/50   -   loss: 0.01195   -   val_loss: 0.01643
# Epoch 34/50   -   loss: 0.01178   -   val_loss: 0.01642
# Epoch 35/50   -   loss: 0.01157   -   val_loss: 0.01647
# Epoch 36/50   -   loss: 0.01149   -   val_loss: 0.01651
# Epoch 37/50   -   loss: 0.01124   -   val_loss: 0.01650
# Epoch 38/50   -   loss: 0.01112   -   val_loss: 0.01652
# Epoch 39/50   -   loss: 0.01095   -   val_loss: 0.01655
# Epoch 40/50   -   loss: 0.01071   -   val_loss: 0.01661
# Epoch 41/50   -   loss: 0.01064   -   val_loss: 0.01658
# Epoch 42/50   -   loss: 0.01044   -   val_loss: 0.01663
# Epoch 43/50   -   loss: 0.01030   -   val_loss: 0.01668
# Epoch 44/50   -   loss: 0.01008   -   val_loss: 0.01671
# Epoch 45/50   -   loss: 0.00999   -   val_loss: 0.01672
# Epoch 46/50   -   loss: 0.00981   -   val_loss: 0.01676
# Epoch 47/50   -   loss: 0.00964   -   val_loss: 0.01680
# Epoch 48/50   -   loss: 0.00942   -   val_loss: 0.01681
# Epoch 49/50   -   loss: 0.00932   -   val_loss: 0.01682
# Epoch 50/50   -   loss: 0.00917   -   val_loss: 0.01693
# Train fold 2
# Epoch 1/50   -   loss: 0.37871   -   val_loss: 0.06499
# Epoch 2/50   -   loss: 0.04272   -   val_loss: 0.02856
# Epoch 3/50   -   loss: 0.02645   -   val_loss: 0.02227
# Epoch 4/50   -   loss: 0.02218   -   val_loss: 0.02020
# Epoch 5/50   -   loss: 0.02062   -   val_loss: 0.01917
# Epoch 6/50   -   loss: 0.01971   -   val_loss: 0.01845
# Epoch 7/50   -   loss: 0.01902   -   val_loss: 0.01800
# Epoch 8/50   -   loss: 0.01853   -   val_loss: 0.01751
# Epoch 9/50   -   loss: 0.01820   -   val_loss: 0.01737
# Epoch 10/50   -   loss: 0.01775   -   val_loss: 0.01692
# Epoch 11/50   -   loss: 0.01733   -   val_loss: 0.01681
# Epoch 12/50   -   loss: 0.01699   -   val_loss: 0.01671
# Epoch 13/50   -   loss: 0.01681   -   val_loss: 0.01660
# Epoch 14/50   -   loss: 0.01648   -   val_loss: 0.01643
# Epoch 15/50   -   loss: 0.01624   -   val_loss: 0.01638
# Epoch 16/50   -   loss: 0.01606   -   val_loss: 0.01631
# Epoch 17/50   -   loss: 0.01596   -   val_loss: 0.01638
# Epoch 18/50   -   loss: 0.01563   -   val_loss: 0.01609
# Epoch 19/50   -   loss: 0.01551   -   val_loss: 0.01602
# Epoch 20/50   -   loss: 0.01533   -   val_loss: 0.01603
# Epoch 21/50   -   loss: 0.01518   -   val_loss: 0.01596
# Epoch 22/50   -   loss: 0.01508   -   val_loss: 0.01589
# Epoch 23/50   -   loss: 0.01492   -   val_loss: 0.01604
# Epoch 24/50   -   loss: 0.01481   -   val_loss: 0.01594
# Epoch 25/50   -   loss: 0.01466   -   val_loss: 0.01606
# Epoch 26/50   -   loss: 0.01456   -   val_loss: 0.01594
# Epoch    26: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 27/50   -   loss: 0.01368   -   val_loss: 0.01579
# Epoch 28/50   -   loss: 0.01330   -   val_loss: 0.01573
# Epoch 29/50   -   loss: 0.01303   -   val_loss: 0.01572
# Epoch 30/50   -   loss: 0.01280   -   val_loss: 0.01571
# Epoch 31/50   -   loss: 0.01260   -   val_loss: 0.01569
# Epoch 32/50   -   loss: 0.01241   -   val_loss: 0.01572
# Epoch 33/50   -   loss: 0.01221   -   val_loss: 0.01572
# Epoch 34/50   -   loss: 0.01203   -   val_loss: 0.01571
# Epoch 35/50   -   loss: 0.01190   -   val_loss: 0.01574
# Epoch 36/50   -   loss: 0.01173   -   val_loss: 0.01573
# Epoch 37/50   -   loss: 0.01150   -   val_loss: 0.01572
# Epoch 38/50   -   loss: 0.01134   -   val_loss: 0.01574
# Epoch 39/50   -   loss: 0.01121   -   val_loss: 0.01575
# Epoch 40/50   -   loss: 0.01109   -   val_loss: 0.01575
# Epoch 41/50   -   loss: 0.01085   -   val_loss: 0.01577
# Epoch 42/50   -   loss: 0.01068   -   val_loss: 0.01582
# Epoch 43/50   -   loss: 0.01057   -   val_loss: 0.01583
# Epoch 44/50   -   loss: 0.01042   -   val_loss: 0.01584
# Epoch 45/50   -   loss: 0.01029   -   val_loss: 0.01584
# Epoch 46/50   -   loss: 0.01010   -   val_loss: 0.01589
# Epoch 47/50   -   loss: 0.00997   -   val_loss: 0.01594
# Epoch 48/50   -   loss: 0.00979   -   val_loss: 0.01591
# Epoch 49/50   -   loss: 0.00959   -   val_loss: 0.01595
# Epoch 50/50   -   loss: 0.00958   -   val_loss: 0.01599
# Train fold 3
# Epoch 1/50   -   loss: 0.37929   -   val_loss: 0.06849
# Epoch 2/50   -   loss: 0.04258   -   val_loss: 0.02595
# Epoch 3/50   -   loss: 0.02614   -   val_loss: 0.02176
# Epoch 4/50   -   loss: 0.02210   -   val_loss: 0.02015
# Epoch 5/50   -   loss: 0.02071   -   val_loss: 0.01915
# Epoch 6/50   -   loss: 0.01984   -   val_loss: 0.01864
# Epoch 7/50   -   loss: 0.01911   -   val_loss: 0.01807
# Epoch 8/50   -   loss: 0.01861   -   val_loss: 0.01769
# Epoch 9/50   -   loss: 0.01806   -   val_loss: 0.01750
# Epoch 10/50   -   loss: 0.01780   -   val_loss: 0.01717
# Epoch 11/50   -   loss: 0.01751   -   val_loss: 0.01708
# Epoch 12/50   -   loss: 0.01722   -   val_loss: 0.01686
# Epoch 13/50   -   loss: 0.01683   -   val_loss: 0.01690
# Epoch 14/50   -   loss: 0.01658   -   val_loss: 0.01660
# Epoch 15/50   -   loss: 0.01634   -   val_loss: 0.01650
# Epoch 16/50   -   loss: 0.01606   -   val_loss: 0.01652
# Epoch 17/50   -   loss: 0.01594   -   val_loss: 0.01634
# Epoch 18/50   -   loss: 0.01564   -   val_loss: 0.01643
# Epoch 19/50   -   loss: 0.01553   -   val_loss: 0.01627
# Epoch 20/50   -   loss: 0.01542   -   val_loss: 0.01625
# Epoch 21/50   -   loss: 0.01521   -   val_loss: 0.01632
# Epoch 22/50   -   loss: 0.01509   -   val_loss: 0.01619
# Epoch 23/50   -   loss: 0.01488   -   val_loss: 0.01626
# Epoch 24/50   -   loss: 0.01480   -   val_loss: 0.01627
# Epoch 25/50   -   loss: 0.01465   -   val_loss: 0.01621
# Epoch 26/50   -   loss: 0.01453   -   val_loss: 0.01639
# Epoch    26: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 27/50   -   loss: 0.01367   -   val_loss: 0.01607
# Epoch 28/50   -   loss: 0.01326   -   val_loss: 0.01604
# Epoch 29/50   -   loss: 0.01295   -   val_loss: 0.01599
# Epoch 30/50   -   loss: 0.01280   -   val_loss: 0.01595
# Epoch 31/50   -   loss: 0.01251   -   val_loss: 0.01595
# Epoch 32/50   -   loss: 0.01234   -   val_loss: 0.01599
# Epoch 33/50   -   loss: 0.01210   -   val_loss: 0.01595
# Epoch 34/50   -   loss: 0.01198   -   val_loss: 0.01598
# Epoch 35/50   -   loss: 0.01178   -   val_loss: 0.01599
# Epoch 36/50   -   loss: 0.01159   -   val_loss: 0.01598
# Epoch 37/50   -   loss: 0.01150   -   val_loss: 0.01603
# Epoch 38/50   -   loss: 0.01133   -   val_loss: 0.01601
# Epoch 39/50   -   loss: 0.01112   -   val_loss: 0.01606
# Epoch 40/50   -   loss: 0.01095   -   val_loss: 0.01603
# Epoch 41/50   -   loss: 0.01078   -   val_loss: 0.01605
# Epoch 42/50   -   loss: 0.01065   -   val_loss: 0.01608
# Epoch 43/50   -   loss: 0.01045   -   val_loss: 0.01614
# Epoch 44/50   -   loss: 0.01028   -   val_loss: 0.01611
# Epoch 45/50   -   loss: 0.01012   -   val_loss: 0.01620
# Epoch 46/50   -   loss: 0.01001   -   val_loss: 0.01616
# Epoch 47/50   -   loss: 0.00986   -   val_loss: 0.01621
# Epoch 48/50   -   loss: 0.00964   -   val_loss: 0.01627
# Epoch 49/50   -   loss: 0.00955   -   val_loss: 0.01630
# Epoch 50/50   -   loss: 0.00939   -   val_loss: 0.01632
# Train fold 4
# Epoch 1/50   -   loss: 0.37879   -   val_loss: 0.06638
# Epoch 2/50   -   loss: 0.04274   -   val_loss: 0.02656
# Epoch 3/50   -   loss: 0.02619   -   val_loss: 0.02227
# Epoch 4/50   -   loss: 0.02257   -   val_loss: 0.02019
# Epoch 5/50   -   loss: 0.02093   -   val_loss: 0.01906
# Epoch 6/50   -   loss: 0.01988   -   val_loss: 0.01844
# Epoch 7/50   -   loss: 0.01916   -   val_loss: 0.01807
# Epoch 8/50   -   loss: 0.01860   -   val_loss: 0.01764
# Epoch 9/50   -   loss: 0.01814   -   val_loss: 0.01724
# Epoch 10/50   -   loss: 0.01781   -   val_loss: 0.01727
# Epoch 11/50   -   loss: 0.01742   -   val_loss: 0.01702
# Epoch 12/50   -   loss: 0.01718   -   val_loss: 0.01688
# Epoch 13/50   -   loss: 0.01697   -   val_loss: 0.01659
# Epoch 14/50   -   loss: 0.01664   -   val_loss: 0.01647
# Epoch 15/50   -   loss: 0.01640   -   val_loss: 0.01633
# Epoch 16/50   -   loss: 0.01604   -   val_loss: 0.01626
# Epoch 17/50   -   loss: 0.01589   -   val_loss: 0.01618
# Epoch 18/50   -   loss: 0.01579   -   val_loss: 0.01620
# Epoch 19/50   -   loss: 0.01550   -   val_loss: 0.01610
# Epoch 20/50   -   loss: 0.01541   -   val_loss: 0.01622
# Epoch 21/50   -   loss: 0.01527   -   val_loss: 0.01605
# Epoch 22/50   -   loss: 0.01513   -   val_loss: 0.01609
# Epoch 23/50   -   loss: 0.01500   -   val_loss: 0.01603
# Epoch 24/50   -   loss: 0.01479   -   val_loss: 0.01601
# Epoch 25/50   -   loss: 0.01467   -   val_loss: 0.01599
# Epoch 26/50   -   loss: 0.01463   -   val_loss: 0.01611
# Epoch 27/50   -   loss: 0.01445   -   val_loss: 0.01597
# Epoch 28/50   -   loss: 0.01431   -   val_loss: 0.01614
# Epoch 29/50   -   loss: 0.01427   -   val_loss: 0.01606
# Epoch 30/50   -   loss: 0.01407   -   val_loss: 0.01608
# Epoch 31/50   -   loss: 0.01402   -   val_loss: 0.01613
# Epoch    31: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 32/50   -   loss: 0.01307   -   val_loss: 0.01592
# Epoch 33/50   -   loss: 0.01270   -   val_loss: 0.01586
# Epoch 34/50   -   loss: 0.01232   -   val_loss: 0.01582
# Epoch 35/50   -   loss: 0.01209   -   val_loss: 0.01584
# Epoch 36/50   -   loss: 0.01184   -   val_loss: 0.01582
# Epoch 37/50   -   loss: 0.01167   -   val_loss: 0.01587
# Epoch 38/50   -   loss: 0.01145   -   val_loss: 0.01586
# Epoch 39/50   -   loss: 0.01131   -   val_loss: 0.01587
# Epoch 40/50   -   loss: 0.01117   -   val_loss: 0.01588
# Epoch 41/50   -   loss: 0.01099   -   val_loss: 0.01594
# Epoch 42/50   -   loss: 0.01083   -   val_loss: 0.01596
# Epoch 43/50   -   loss: 0.01073   -   val_loss: 0.01594
# Epoch 44/50   -   loss: 0.01047   -   val_loss: 0.01596
# Epoch 45/50   -   loss: 0.01033   -   val_loss: 0.01600
# Epoch 46/50   -   loss: 0.01015   -   val_loss: 0.01604
# Epoch 47/50   -   loss: 0.01001   -   val_loss: 0.01604
# Epoch 48/50   -   loss: 0.00989   -   val_loss: 0.01609
# Epoch 49/50   -   loss: 0.00972   -   val_loss: 0.01612
# Epoch 50/50   -   loss: 0.00954   -   val_loss: 0.01616
# Train fold 5
# Epoch 1/50   -   loss: 0.38183   -   val_loss: 0.06648
# Epoch 2/50   -   loss: 0.04278   -   val_loss: 0.02632
# Epoch 3/50   -   loss: 0.02582   -   val_loss: 0.02230
# Epoch 4/50   -   loss: 0.02278   -   val_loss: 0.01998
# Epoch 5/50   -   loss: 0.02072   -   val_loss: 0.01894
# Epoch 6/50   -   loss: 0.01994   -   val_loss: 0.01869
# Epoch 7/50   -   loss: 0.01907   -   val_loss: 0.01788
# Epoch 8/50   -   loss: 0.01875   -   val_loss: 0.01791
# Epoch 9/50   -   loss: 0.01839   -   val_loss: 0.01735
# Epoch 10/50   -   loss: 0.01777   -   val_loss: 0.01719
# Epoch 11/50   -   loss: 0.01742   -   val_loss: 0.01714
# Epoch 12/50   -   loss: 0.01709   -   val_loss: 0.01684
# Epoch 13/50   -   loss: 0.01673   -   val_loss: 0.01678
# Epoch 14/50   -   loss: 0.01655   -   val_loss: 0.01657
# Epoch 15/50   -   loss: 0.01628   -   val_loss: 0.01665
# Epoch 16/50   -   loss: 0.01611   -   val_loss: 0.01650
# Epoch 17/50   -   loss: 0.01589   -   val_loss: 0.01644
# Epoch 18/50   -   loss: 0.01567   -   val_loss: 0.01651
# Epoch 19/50   -   loss: 0.01555   -   val_loss: 0.01632
# Epoch 20/50   -   loss: 0.01544   -   val_loss: 0.01623
# Epoch 21/50   -   loss: 0.01523   -   val_loss: 0.01623
# Epoch 22/50   -   loss: 0.01508   -   val_loss: 0.01628
# Epoch 23/50   -   loss: 0.01489   -   val_loss: 0.01618
# Epoch 24/50   -   loss: 0.01478   -   val_loss: 0.01615
# Epoch 25/50   -   loss: 0.01469   -   val_loss: 0.01622
# Epoch 26/50   -   loss: 0.01447   -   val_loss: 0.01619
# Epoch 27/50   -   loss: 0.01445   -   val_loss: 0.01626
# Epoch 28/50   -   loss: 0.01433   -   val_loss: 0.01621
# Epoch    28: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 29/50   -   loss: 0.01342   -   val_loss: 0.01598
# Epoch 30/50   -   loss: 0.01297   -   val_loss: 0.01595
# Epoch 31/50   -   loss: 0.01280   -   val_loss: 0.01593
# Epoch 32/50   -   loss: 0.01244   -   val_loss: 0.01591
# Epoch 33/50   -   loss: 0.01223   -   val_loss: 0.01594
# Epoch 34/50   -   loss: 0.01211   -   val_loss: 0.01595
# Epoch 35/50   -   loss: 0.01188   -   val_loss: 0.01595
# Epoch 36/50   -   loss: 0.01171   -   val_loss: 0.01596
# Epoch 37/50   -   loss: 0.01152   -   val_loss: 0.01599
# Epoch 38/50   -   loss: 0.01138   -   val_loss: 0.01602
# Epoch 39/50   -   loss: 0.01120   -   val_loss: 0.01603
# Epoch 40/50   -   loss: 0.01100   -   val_loss: 0.01603
# Epoch 41/50   -   loss: 0.01088   -   val_loss: 0.01608
# Epoch 42/50   -   loss: 0.01076   -   val_loss: 0.01608
# Epoch 43/50   -   loss: 0.01058   -   val_loss: 0.01610
# Epoch 44/50   -   loss: 0.01044   -   val_loss: 0.01612
# Epoch 45/50   -   loss: 0.01024   -   val_loss: 0.01612
# Epoch 46/50   -   loss: 0.01010   -   val_loss: 0.01620
# Epoch 47/50   -   loss: 0.00994   -   val_loss: 0.01617
# Epoch 48/50   -   loss: 0.00981   -   val_loss: 0.01619
# Epoch 49/50   -   loss: 0.00962   -   val_loss: 0.01623
# Epoch 50/50   -   loss: 0.00951   -   val_loss: 0.01629
# Train fold 6
# Epoch 1/50   -   loss: 0.37994   -   val_loss: 0.06328
# Epoch 2/50   -   loss: 0.04310   -   val_loss: 0.02713
# Epoch 3/50   -   loss: 0.02591   -   val_loss: 0.02214
# Epoch 4/50   -   loss: 0.02223   -   val_loss: 0.02027
# Epoch 5/50   -   loss: 0.02068   -   val_loss: 0.01927
# Epoch 6/50   -   loss: 0.01965   -   val_loss: 0.01837
# Epoch 7/50   -   loss: 0.01908   -   val_loss: 0.01813
# Epoch 8/50   -   loss: 0.01853   -   val_loss: 0.01751
# Epoch 9/50   -   loss: 0.01810   -   val_loss: 0.01720
# Epoch 10/50   -   loss: 0.01794   -   val_loss: 0.01710
# Epoch 11/50   -   loss: 0.01759   -   val_loss: 0.01699
# Epoch 12/50   -   loss: 0.01717   -   val_loss: 0.01667
# Epoch 13/50   -   loss: 0.01684   -   val_loss: 0.01652
# Epoch 14/50   -   loss: 0.01678   -   val_loss: 0.01639
# Epoch 15/50   -   loss: 0.01637   -   val_loss: 0.01636
# Epoch 16/50   -   loss: 0.01612   -   val_loss: 0.01630
# Epoch 17/50   -   loss: 0.01588   -   val_loss: 0.01615
# Epoch 18/50   -   loss: 0.01562   -   val_loss: 0.01602
# Epoch 19/50   -   loss: 0.01549   -   val_loss: 0.01603
# Epoch 20/50   -   loss: 0.01533   -   val_loss: 0.01598
# Epoch 21/50   -   loss: 0.01512   -   val_loss: 0.01613
# Epoch 22/50   -   loss: 0.01497   -   val_loss: 0.01603
# Epoch 23/50   -   loss: 0.01490   -   val_loss: 0.01599
# Epoch 24/50   -   loss: 0.01477   -   val_loss: 0.01603
# Epoch    24: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 25/50   -   loss: 0.01386   -   val_loss: 0.01578
# Epoch 26/50   -   loss: 0.01344   -   val_loss: 0.01573
# Epoch 27/50   -   loss: 0.01322   -   val_loss: 0.01568
# Epoch 28/50   -   loss: 0.01298   -   val_loss: 0.01572
# Epoch 29/50   -   loss: 0.01279   -   val_loss: 0.01568
# Epoch 30/50   -   loss: 0.01257   -   val_loss: 0.01569
# Epoch 31/50   -   loss: 0.01240   -   val_loss: 0.01570
# Epoch 32/50   -   loss: 0.01224   -   val_loss: 0.01567
# Epoch 33/50   -   loss: 0.01212   -   val_loss: 0.01571
# Epoch 34/50   -   loss: 0.01189   -   val_loss: 0.01579
# Epoch 35/50   -   loss: 0.01173   -   val_loss: 0.01575
# Epoch 36/50   -   loss: 0.01156   -   val_loss: 0.01576
# Epoch 37/50   -   loss: 0.01141   -   val_loss: 0.01578
# Epoch 38/50   -   loss: 0.01122   -   val_loss: 0.01578
# Epoch 39/50   -   loss: 0.01110   -   val_loss: 0.01580
# Epoch 40/50   -   loss: 0.01085   -   val_loss: 0.01583
# Epoch 41/50   -   loss: 0.01075   -   val_loss: 0.01580
# Epoch 42/50   -   loss: 0.01056   -   val_loss: 0.01588
# Epoch 43/50   -   loss: 0.01035   -   val_loss: 0.01592
# Epoch 44/50   -   loss: 0.01019   -   val_loss: 0.01588
# Epoch 45/50   -   loss: 0.01011   -   val_loss: 0.01596
# Epoch 46/50   -   loss: 0.00989   -   val_loss: 0.01603
# Epoch 47/50   -   loss: 0.00972   -   val_loss: 0.01599
# Epoch 48/50   -   loss: 0.00963   -   val_loss: 0.01601
# Epoch 49/50   -   loss: 0.00938   -   val_loss: 0.01605
# Epoch 50/50   -   loss: 0.00921   -   val_loss: 0.01614
# {'train': 0.012243488516945105, 'val': 0.015673546236939728}

# %%
run_eval_for_model(Model0, 0, train_X0, train_Y0, test_X0)
# Out:
# Overall score is 0.01484

# %%
class Model1(nn.Module):
    def __init__(self, num_columns):
        super(Model1, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_columns)
        self.dropout1 = nn.Dropout(0.2)
        self.dense1 = nn.utils.weight_norm(nn.Linear(num_columns, 2048))
        
        self.batch_norm2 = nn.BatchNorm1d(2048)
        self.dropout2 = nn.Dropout(0.5)
        self.dense2 = nn.utils.weight_norm(nn.Linear(2048, 1024))
        
        self.batch_norm3 = nn.BatchNorm1d(1024)
        self.dropout3 = nn.Dropout(0.5)
        self.dense3 = nn.utils.weight_norm(nn.Linear(1024, 206))
    
    def forward(self, x):
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        x = F.relu(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = F.relu(self.dense2(x))
        
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x = F.sigmoid(self.dense3(x))
        
        return x

# %%
train_Y1 = train_Y.reset_index(drop=True)
train_X1 = train_X.drop(columns=['real_drug']).reset_index(drop=True)
test_X1 = test_X.drop(columns=['real_drug'])

features = list(train_X1.columns)
nfeatures = len(features)
features_g = [col for col in train_X1.columns if 'g-' in col]
features_c = [col for col in train_X1.columns if 'c-' in col]
features_gc = features_g + features_c
targets = list(train_Y1.columns)
ntargets = len(targets)

train_Y1 = train_Y1.values
train_X1 = train_X1.values
test_X1 = test_X1.values

# %%
run_CV_for_model(Model1, 1, train_X1, train_Y1, test_X1)
# Out:
# Train fold 1
# Epoch 1/50   -   loss: 0.35275   -   val_loss: 0.05716
# Epoch 2/50   -   loss: 0.03776   -   val_loss: 0.02479
# Epoch 3/50   -   loss: 0.02354   -   val_loss: 0.02100
# Epoch 4/50   -   loss: 0.02070   -   val_loss: 0.01921
# Epoch 5/50   -   loss: 0.01932   -   val_loss: 0.01823
# Epoch 6/50   -   loss: 0.01858   -   val_loss: 0.01764
# Epoch 7/50   -   loss: 0.01789   -   val_loss: 0.01747
# Epoch 8/50   -   loss: 0.01733   -   val_loss: 0.01672
# Epoch 9/50   -   loss: 0.01718   -   val_loss: 0.01670
# Epoch 10/50   -   loss: 0.01690   -   val_loss: 0.01644
# Epoch 11/50   -   loss: 0.01647   -   val_loss: 0.01624
# Epoch 12/50   -   loss: 0.01626   -   val_loss: 0.01613
# Epoch 13/50   -   loss: 0.01585   -   val_loss: 0.01586
# Epoch 14/50   -   loss: 0.01574   -   val_loss: 0.01582
# Epoch 15/50   -   loss: 0.01553   -   val_loss: 0.01573
# Epoch 16/50   -   loss: 0.01526   -   val_loss: 0.01560
# Epoch 17/50   -   loss: 0.01518   -   val_loss: 0.01563
# Epoch 18/50   -   loss: 0.01500   -   val_loss: 0.01556
# Epoch 19/50   -   loss: 0.01486   -   val_loss: 0.01546
# Epoch 20/50   -   loss: 0.01479   -   val_loss: 0.01551
# Epoch 21/50   -   loss: 0.01475   -   val_loss: 0.01532
# Epoch 22/50   -   loss: 0.01445   -   val_loss: 0.01526
# Epoch 23/50   -   loss: 0.01442   -   val_loss: 0.01528
# Epoch 24/50   -   loss: 0.01442   -   val_loss: 0.01525
# Epoch 25/50   -   loss: 0.01418   -   val_loss: 0.01521
# Epoch 26/50   -   loss: 0.01408   -   val_loss: 0.01522
# Epoch 27/50   -   loss: 0.01405   -   val_loss: 0.01533
# Epoch 28/50   -   loss: 0.01396   -   val_loss: 0.01533
# Epoch 29/50   -   loss: 0.01399   -   val_loss: 0.01528
# Epoch    29: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 30/50   -   loss: 0.01318   -   val_loss: 0.01506
# Epoch 31/50   -   loss: 0.01283   -   val_loss: 0.01501
# Epoch 32/50   -   loss: 0.01264   -   val_loss: 0.01506
# Epoch 33/50   -   loss: 0.01250   -   val_loss: 0.01501
# Epoch 34/50   -   loss: 0.01234   -   val_loss: 0.01496
# Epoch 35/50   -   loss: 0.01212   -   val_loss: 0.01500
# Epoch 36/50   -   loss: 0.01199   -   val_loss: 0.01500
# Epoch 37/50   -   loss: 0.01184   -   val_loss: 0.01505
# Epoch 38/50   -   loss: 0.01170   -   val_loss: 0.01499
# Epoch 39/50   -   loss: 0.01161   -   val_loss: 0.01503
# Epoch 40/50   -   loss: 0.01147   -   val_loss: 0.01507
# Epoch 41/50   -   loss: 0.01136   -   val_loss: 0.01505
# Epoch 42/50   -   loss: 0.01121   -   val_loss: 0.01507
# Epoch 43/50   -   loss: 0.01099   -   val_loss: 0.01502
# Epoch 44/50   -   loss: 0.01093   -   val_loss: 0.01508
# Epoch 45/50   -   loss: 0.01084   -   val_loss: 0.01507
# Epoch 46/50   -   loss: 0.01068   -   val_loss: 0.01507
# Epoch 47/50   -   loss: 0.01054   -   val_loss: 0.01520
# Epoch 48/50   -   loss: 0.01051   -   val_loss: 0.01514
# Epoch 49/50   -   loss: 0.01024   -   val_loss: 0.01525
# Epoch 50/50   -   loss: 0.01020   -   val_loss: 0.01521
# Train fold 2
# Epoch 1/50   -   loss: 0.35493   -   val_loss: 0.05421
# Epoch 2/50   -   loss: 0.03753   -   val_loss: 0.02515
# Epoch 3/50   -   loss: 0.02357   -   val_loss: 0.02073
# Epoch 4/50   -   loss: 0.02075   -   val_loss: 0.01925
# Epoch 5/50   -   loss: 0.01930   -   val_loss: 0.01841
# Epoch 6/50   -   loss: 0.01851   -   val_loss: 0.01770
# Epoch 7/50   -   loss: 0.01777   -   val_loss: 0.01720
# Epoch 8/50   -   loss: 0.01736   -   val_loss: 0.01675
# Epoch 9/50   -   loss: 0.01714   -   val_loss: 0.01681
# Epoch 10/50   -   loss: 0.01675   -   val_loss: 0.01626
# Epoch 11/50   -   loss: 0.01638   -   val_loss: 0.01624
# Epoch 12/50   -   loss: 0.01639   -   val_loss: 0.01597
# Epoch 13/50   -   loss: 0.01587   -   val_loss: 0.01583
# Epoch 14/50   -   loss: 0.01573   -   val_loss: 0.01576
# Epoch 15/50   -   loss: 0.01547   -   val_loss: 0.01568
# Epoch 16/50   -   loss: 0.01532   -   val_loss: 0.01559
# Epoch 17/50   -   loss: 0.01519   -   val_loss: 0.01543
# Epoch 18/50   -   loss: 0.01497   -   val_loss: 0.01540
# Epoch 19/50   -   loss: 0.01482   -   val_loss: 0.01534
# Epoch 20/50   -   loss: 0.01481   -   val_loss: 0.01534
# Epoch 21/50   -   loss: 0.01469   -   val_loss: 0.01537
# Epoch 22/50   -   loss: 0.01453   -   val_loss: 0.01531
# Epoch 23/50   -   loss: 0.01449   -   val_loss: 0.01519
# Epoch 24/50   -   loss: 0.01431   -   val_loss: 0.01535
# Epoch 25/50   -   loss: 0.01412   -   val_loss: 0.01521
# Epoch 26/50   -   loss: 0.01402   -   val_loss: 0.01516
# Epoch 27/50   -   loss: 0.01403   -   val_loss: 0.01518
# Epoch 28/50   -   loss: 0.01407   -   val_loss: 0.01510
# Epoch 29/50   -   loss: 0.01397   -   val_loss: 0.01517
# Epoch 30/50   -   loss: 0.01394   -   val_loss: 0.01519
# Epoch 31/50   -   loss: 0.01386   -   val_loss: 0.01519
# Epoch 32/50   -   loss: 0.01390   -   val_loss: 0.01513
# Epoch    32: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 33/50   -   loss: 0.01314   -   val_loss: 0.01499
# Epoch 34/50   -   loss: 0.01275   -   val_loss: 0.01490
# Epoch 35/50   -   loss: 0.01260   -   val_loss: 0.01485
# Epoch 36/50   -   loss: 0.01233   -   val_loss: 0.01486
# Epoch 37/50   -   loss: 0.01214   -   val_loss: 0.01483
# Epoch 38/50   -   loss: 0.01194   -   val_loss: 0.01489
# Epoch 39/50   -   loss: 0.01180   -   val_loss: 0.01483
# Epoch 40/50   -   loss: 0.01170   -   val_loss: 0.01488
# Epoch 41/50   -   loss: 0.01152   -   val_loss: 0.01489
# Epoch 42/50   -   loss: 0.01152   -   val_loss: 0.01490
# Epoch 43/50   -   loss: 0.01125   -   val_loss: 0.01500
# Epoch 44/50   -   loss: 0.01113   -   val_loss: 0.01492
# Epoch 45/50   -   loss: 0.01103   -   val_loss: 0.01490
# Epoch 46/50   -   loss: 0.01088   -   val_loss: 0.01495
# Epoch 47/50   -   loss: 0.01074   -   val_loss: 0.01494
# Epoch 48/50   -   loss: 0.01067   -   val_loss: 0.01499
# Epoch 49/50   -   loss: 0.01057   -   val_loss: 0.01494
# Epoch 50/50   -   loss: 0.01037   -   val_loss: 0.01502
# Train fold 3
# Epoch 1/50   -   loss: 0.35166   -   val_loss: 0.06144
# Epoch 2/50   -   loss: 0.03732   -   val_loss: 0.02480
# Epoch 3/50   -   loss: 0.02419   -   val_loss: 0.02118
# Epoch 4/50   -   loss: 0.02175   -   val_loss: 0.01907
# Epoch 5/50   -   loss: 0.01992   -   val_loss: 0.01821
# Epoch 6/50   -   loss: 0.01945   -   val_loss: 0.01798
# Epoch 7/50   -   loss: 0.01840   -   val_loss: 0.01741
# Epoch 8/50   -   loss: 0.01789   -   val_loss: 0.01708
# Epoch 9/50   -   loss: 0.01733   -   val_loss: 0.01677
# Epoch 10/50   -   loss: 0.01713   -   val_loss: 0.01665
# Epoch 11/50   -   loss: 0.01678   -   val_loss: 0.01631
# Epoch 12/50   -   loss: 0.01654   -   val_loss: 0.01612
# Epoch 13/50   -   loss: 0.01628   -   val_loss: 0.01605
# Epoch 14/50   -   loss: 0.01623   -   val_loss: 0.01594
# Epoch 15/50   -   loss: 0.01598   -   val_loss: 0.01591
# Epoch 16/50   -   loss: 0.01571   -   val_loss: 0.01565
# Epoch 17/50   -   loss: 0.01555   -   val_loss: 0.01551
# Epoch 18/50   -   loss: 0.01536   -   val_loss: 0.01553
# Epoch 19/50   -   loss: 0.01523   -   val_loss: 0.01558
# Epoch 20/50   -   loss: 0.01503   -   val_loss: 0.01535
# Epoch 21/50   -   loss: 0.01490   -   val_loss: 0.01543
# Epoch 22/50   -   loss: 0.01487   -   val_loss: 0.01535
# Epoch 23/50   -   loss: 0.01471   -   val_loss: 0.01527
# Epoch 24/50   -   loss: 0.01445   -   val_loss: 0.01518
# Epoch 25/50   -   loss: 0.01446   -   val_loss: 0.01516
# Epoch 26/50   -   loss: 0.01434   -   val_loss: 0.01520
# Epoch 27/50   -   loss: 0.01424   -   val_loss: 0.01519
# Epoch 28/50   -   loss: 0.01415   -   val_loss: 0.01522
# Epoch 29/50   -   loss: 0.01417   -   val_loss: 0.01510
# Epoch 30/50   -   loss: 0.01415   -   val_loss: 0.01519
# Epoch 31/50   -   loss: 0.01405   -   val_loss: 0.01517
# Epoch 32/50   -   loss: 0.01401   -   val_loss: 0.01521
# Epoch 33/50   -   loss: 0.01396   -   val_loss: 0.01516
# Epoch    33: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 34/50   -   loss: 0.01313   -   val_loss: 0.01498
# Epoch 35/50   -   loss: 0.01280   -   val_loss: 0.01492
# Epoch 36/50   -   loss: 0.01264   -   val_loss: 0.01493
# Epoch 37/50   -   loss: 0.01250   -   val_loss: 0.01493
# Epoch 38/50   -   loss: 0.01234   -   val_loss: 0.01488
# Epoch 39/50   -   loss: 0.01213   -   val_loss: 0.01486
# Epoch 40/50   -   loss: 0.01196   -   val_loss: 0.01488
# Epoch 41/50   -   loss: 0.01184   -   val_loss: 0.01487
# Epoch 42/50   -   loss: 0.01169   -   val_loss: 0.01490
# Epoch 43/50   -   loss: 0.01153   -   val_loss: 0.01497
# Epoch 44/50   -   loss: 0.01139   -   val_loss: 0.01490
# Epoch 45/50   -   loss: 0.01126   -   val_loss: 0.01493
# Epoch 46/50   -   loss: 0.01115   -   val_loss: 0.01501
# Epoch 47/50   -   loss: 0.01106   -   val_loss: 0.01493
# Epoch 48/50   -   loss: 0.01084   -   val_loss: 0.01495
# Epoch 49/50   -   loss: 0.01069   -   val_loss: 0.01501
# Epoch 50/50   -   loss: 0.01062   -   val_loss: 0.01501
# Train fold 4
# Epoch 1/50   -   loss: 0.35058   -   val_loss: 0.05238
# Epoch 2/50   -   loss: 0.03725   -   val_loss: 0.02476
# Epoch 3/50   -   loss: 0.02348   -   val_loss: 0.02092
# Epoch 4/50   -   loss: 0.02058   -   val_loss: 0.01970
# Epoch 5/50   -   loss: 0.01958   -   val_loss: 0.01847
# Epoch 6/50   -   loss: 0.01843   -   val_loss: 0.01793
# Epoch 7/50   -   loss: 0.01825   -   val_loss: 0.01746
# Epoch 8/50   -   loss: 0.01761   -   val_loss: 0.01705
# Epoch 9/50   -   loss: 0.01704   -   val_loss: 0.01663
# Epoch 10/50   -   loss: 0.01657   -   val_loss: 0.01648
# Epoch 11/50   -   loss: 0.01632   -   val_loss: 0.01634
# Epoch 12/50   -   loss: 0.01600   -   val_loss: 0.01627
# Epoch 13/50   -   loss: 0.01588   -   val_loss: 0.01614
# Epoch 14/50   -   loss: 0.01587   -   val_loss: 0.01609
# Epoch 15/50   -   loss: 0.01581   -   val_loss: 0.01585
# Epoch 16/50   -   loss: 0.01544   -   val_loss: 0.01582
# Epoch 17/50   -   loss: 0.01521   -   val_loss: 0.01572
# Epoch 18/50   -   loss: 0.01510   -   val_loss: 0.01576
# Epoch 19/50   -   loss: 0.01494   -   val_loss: 0.01563
# Epoch 20/50   -   loss: 0.01494   -   val_loss: 0.01564
# Epoch 21/50   -   loss: 0.01478   -   val_loss: 0.01560
# Epoch 22/50   -   loss: 0.01449   -   val_loss: 0.01542
# Epoch 23/50   -   loss: 0.01438   -   val_loss: 0.01551
# Epoch 24/50   -   loss: 0.01424   -   val_loss: 0.01549
# Epoch 25/50   -   loss: 0.01416   -   val_loss: 0.01547
# Epoch 26/50   -   loss: 0.01407   -   val_loss: 0.01550
# Epoch    26: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 27/50   -   loss: 0.01333   -   val_loss: 0.01514
# Epoch 28/50   -   loss: 0.01302   -   val_loss: 0.01511
# Epoch 29/50   -   loss: 0.01285   -   val_loss: 0.01503
# Epoch 30/50   -   loss: 0.01260   -   val_loss: 0.01503
# Epoch 31/50   -   loss: 0.01250   -   val_loss: 0.01503
# Epoch 32/50   -   loss: 0.01230   -   val_loss: 0.01501
# Epoch 33/50   -   loss: 0.01220   -   val_loss: 0.01501
# Epoch 34/50   -   loss: 0.01209   -   val_loss: 0.01505
# Epoch 35/50   -   loss: 0.01191   -   val_loss: 0.01504
# Epoch 36/50   -   loss: 0.01176   -   val_loss: 0.01503
# Epoch 37/50   -   loss: 0.01156   -   val_loss: 0.01506
# Epoch 38/50   -   loss: 0.01148   -   val_loss: 0.01509
# Epoch 39/50   -   loss: 0.01136   -   val_loss: 0.01511
# Epoch 40/50   -   loss: 0.01125   -   val_loss: 0.01512
# Epoch 41/50   -   loss: 0.01104   -   val_loss: 0.01512
# Epoch 42/50   -   loss: 0.01090   -   val_loss: 0.01512
# Epoch 43/50   -   loss: 0.01084   -   val_loss: 0.01521
# Epoch 44/50   -   loss: 0.01059   -   val_loss: 0.01513
# Epoch 45/50   -   loss: 0.01048   -   val_loss: 0.01515
# Epoch 46/50   -   loss: 0.01035   -   val_loss: 0.01518
# Epoch 47/50   -   loss: 0.01024   -   val_loss: 0.01524
# Epoch 48/50   -   loss: 0.01009   -   val_loss: 0.01519
# Epoch 49/50   -   loss: 0.00995   -   val_loss: 0.01522
# Epoch 50/50   -   loss: 0.00976   -   val_loss: 0.01529
# Train fold 5
# Epoch 1/50   -   loss: 0.35341   -   val_loss: 0.05474
# Epoch 2/50   -   loss: 0.03705   -   val_loss: 0.02536
# Epoch 3/50   -   loss: 0.02375   -   val_loss: 0.02017
# Epoch 4/50   -   loss: 0.02082   -   val_loss: 0.01895
# Epoch 5/50   -   loss: 0.01920   -   val_loss: 0.01794
# Epoch 6/50   -   loss: 0.01831   -   val_loss: 0.01758
# Epoch 7/50   -   loss: 0.01788   -   val_loss: 0.01707
# Epoch 8/50   -   loss: 0.01765   -   val_loss: 0.01712
# Epoch 9/50   -   loss: 0.01714   -   val_loss: 0.01657
# Epoch 10/50   -   loss: 0.01674   -   val_loss: 0.01642
# Epoch 11/50   -   loss: 0.01636   -   val_loss: 0.01617
# Epoch 12/50   -   loss: 0.01621   -   val_loss: 0.01636
# Epoch 13/50   -   loss: 0.01612   -   val_loss: 0.01604
# Epoch 14/50   -   loss: 0.01566   -   val_loss: 0.01582
# Epoch 15/50   -   loss: 0.01531   -   val_loss: 0.01568
# Epoch 16/50   -   loss: 0.01513   -   val_loss: 0.01575
# Epoch 17/50   -   loss: 0.01504   -   val_loss: 0.01561
# Epoch 18/50   -   loss: 0.01483   -   val_loss: 0.01553
# Epoch 19/50   -   loss: 0.01483   -   val_loss: 0.01552
# Epoch 20/50   -   loss: 0.01467   -   val_loss: 0.01544
# Epoch 21/50   -   loss: 0.01451   -   val_loss: 0.01542
# Epoch 22/50   -   loss: 0.01449   -   val_loss: 0.01548
# Epoch 23/50   -   loss: 0.01441   -   val_loss: 0.01536
# Epoch 24/50   -   loss: 0.01427   -   val_loss: 0.01542
# Epoch 25/50   -   loss: 0.01419   -   val_loss: 0.01532
# Epoch 26/50   -   loss: 0.01401   -   val_loss: 0.01542
# Epoch 27/50   -   loss: 0.01407   -   val_loss: 0.01548
# Epoch 28/50   -   loss: 0.01412   -   val_loss: 0.01539
# Epoch 29/50   -   loss: 0.01398   -   val_loss: 0.01531
# Epoch 30/50   -   loss: 0.01391   -   val_loss: 0.01532
# Epoch 31/50   -   loss: 0.01386   -   val_loss: 0.01535
# Epoch 32/50   -   loss: 0.01376   -   val_loss: 0.01533
# Epoch 33/50   -   loss: 0.01376   -   val_loss: 0.01534
# Epoch    33: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 34/50   -   loss: 0.01294   -   val_loss: 0.01527
# Epoch 35/50   -   loss: 0.01259   -   val_loss: 0.01507
# Epoch 36/50   -   loss: 0.01237   -   val_loss: 0.01510
# Epoch 37/50   -   loss: 0.01211   -   val_loss: 0.01509
# Epoch 38/50   -   loss: 0.01195   -   val_loss: 0.01506
# Epoch 39/50   -   loss: 0.01181   -   val_loss: 0.01510
# Epoch 40/50   -   loss: 0.01160   -   val_loss: 0.01511
# Epoch 41/50   -   loss: 0.01148   -   val_loss: 0.01510
# Epoch 42/50   -   loss: 0.01141   -   val_loss: 0.01515
# Epoch 43/50   -   loss: 0.01122   -   val_loss: 0.01516
# Epoch 44/50   -   loss: 0.01120   -   val_loss: 0.01519
# Epoch 45/50   -   loss: 0.01096   -   val_loss: 0.01513
# Epoch 46/50   -   loss: 0.01088   -   val_loss: 0.01515
# Epoch 47/50   -   loss: 0.01070   -   val_loss: 0.01518
# Epoch 48/50   -   loss: 0.01058   -   val_loss: 0.01516
# Epoch 49/50   -   loss: 0.01047   -   val_loss: 0.01518
# Epoch 50/50   -   loss: 0.01029   -   val_loss: 0.01524
# Train fold 6
# Epoch 1/50   -   loss: 0.35417   -   val_loss: 0.06030
# Epoch 2/50   -   loss: 0.03833   -   val_loss: 0.02517
# Epoch 3/50   -   loss: 0.02431   -   val_loss: 0.02035
# Epoch 4/50   -   loss: 0.02064   -   val_loss: 0.01881
# Epoch 5/50   -   loss: 0.01937   -   val_loss: 0.01813
# Epoch 6/50   -   loss: 0.01877   -   val_loss: 0.01737
# Epoch 7/50   -   loss: 0.01837   -   val_loss: 0.01717
# Epoch 8/50   -   loss: 0.01777   -   val_loss: 0.01690
# Epoch 9/50   -   loss: 0.01770   -   val_loss: 0.01674
# Epoch 10/50   -   loss: 0.01734   -   val_loss: 0.01642
# Epoch 11/50   -   loss: 0.01679   -   val_loss: 0.01621
# Epoch 12/50   -   loss: 0.01644   -   val_loss: 0.01601
# Epoch 13/50   -   loss: 0.01630   -   val_loss: 0.01601
# Epoch 14/50   -   loss: 0.01610   -   val_loss: 0.01581
# Epoch 15/50   -   loss: 0.01583   -   val_loss: 0.01565
# Epoch 16/50   -   loss: 0.01549   -   val_loss: 0.01558
# Epoch 17/50   -   loss: 0.01535   -   val_loss: 0.01560
# Epoch 18/50   -   loss: 0.01528   -   val_loss: 0.01549
# Epoch 19/50   -   loss: 0.01506   -   val_loss: 0.01547
# Epoch 20/50   -   loss: 0.01507   -   val_loss: 0.01544
# Epoch 21/50   -   loss: 0.01493   -   val_loss: 0.01540
# Epoch 22/50   -   loss: 0.01478   -   val_loss: 0.01535
# Epoch 23/50   -   loss: 0.01462   -   val_loss: 0.01523
# Epoch 24/50   -   loss: 0.01454   -   val_loss: 0.01526
# Epoch 25/50   -   loss: 0.01436   -   val_loss: 0.01530
# Epoch 26/50   -   loss: 0.01441   -   val_loss: 0.01534
# Epoch 27/50   -   loss: 0.01438   -   val_loss: 0.01519
# Epoch 28/50   -   loss: 0.01441   -   val_loss: 0.01531
# Epoch 29/50   -   loss: 0.01435   -   val_loss: 0.01530
# Epoch 30/50   -   loss: 0.01432   -   val_loss: 0.01522
# Epoch 31/50   -   loss: 0.01429   -   val_loss: 0.01522
# Epoch    31: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 32/50   -   loss: 0.01351   -   val_loss: 0.01504
# Epoch 33/50   -   loss: 0.01325   -   val_loss: 0.01488
# Epoch 34/50   -   loss: 0.01287   -   val_loss: 0.01494
# Epoch 35/50   -   loss: 0.01290   -   val_loss: 0.01501
# Epoch 36/50   -   loss: 0.01268   -   val_loss: 0.01486
# Epoch 37/50   -   loss: 0.01245   -   val_loss: 0.01500
# Epoch 38/50   -   loss: 0.01228   -   val_loss: 0.01487
# Epoch 39/50   -   loss: 0.01225   -   val_loss: 0.01485
# Epoch 40/50   -   loss: 0.01211   -   val_loss: 0.01489
# Epoch 41/50   -   loss: 0.01193   -   val_loss: 0.01497
# Epoch 42/50   -   loss: 0.01194   -   val_loss: 0.01489
# Epoch 43/50   -   loss: 0.01176   -   val_loss: 0.01493
# Epoch 44/50   -   loss: 0.01160   -   val_loss: 0.01489
# Epoch 45/50   -   loss: 0.01151   -   val_loss: 0.01497
# Epoch 46/50   -   loss: 0.01130   -   val_loss: 0.01491
# Epoch 47/50   -   loss: 0.01120   -   val_loss: 0.01497
# Epoch 48/50   -   loss: 0.01102   -   val_loss: 0.01500
# Epoch 49/50   -   loss: 0.01093   -   val_loss: 0.01500
# Epoch 50/50   -   loss: 0.01078   -   val_loss: 0.01501
# {'train': 0.012253041182143182, 'val': 0.014853060594759881}

# %%
run_eval_for_model(Model1, 1, train_X0, train_Y0, test_X0)
# Out:
# Overall score is 0.01108

# %%
class Model2(nn.Module):
    def __init__(self, num_columns):
        super(Model2, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_columns)
        self.dropout1 = nn.Dropout(0.2)
        self.dense1 = nn.utils.weight_norm(nn.Linear(num_columns, 2048))
        
        self.batch_norm2 = nn.BatchNorm1d(2048)
        self.dropout2 = nn.Dropout(0.5)
        self.dense2 = nn.utils.weight_norm(nn.Linear(2048, 1024))
        
        self.batch_norm3 = nn.BatchNorm1d(1024)
        self.dropout3 = nn.Dropout(0.5)
        self.dense3 = nn.utils.weight_norm(nn.Linear(1024, 206))
    
    def forward(self, x):
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        x = F.relu(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = F.relu(self.dense2(x))
        
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x = F.sigmoid(self.dense3(x))
        
        return x

# %%
t = test_Y[test_X['real_drug'] == False].copy()
for f in t:
    t[f] = 0
train_Y2 = train_Y.reset_index(drop=True).append(t)
train_X2 = train_X.reset_index(drop=True).append(test_X[test_X['real_drug'] == False]).drop(columns=['real_drug'])
test_X2 = test_X.drop(columns=['real_drug'])

features = list(train_X2.columns)
nfeatures = len(features)
features_g = [col for col in train_X2.columns if 'g-' in col]
features_c = [col for col in train_X2.columns if 'c-' in col]
features_gc = features_g + features_c
targets = list(train_Y2.columns)
ntargets = len(targets)

train_Y2 = train_Y2.values
train_X2 = train_X2.values
test_X2 = test_X2.values

# %%
run_CV_for_model(Model2, 2, train_X2, train_Y2, test_X2)
# Out:
# Train fold 1
# Epoch 1/50   -   loss: 0.34680   -   val_loss: 0.05793
# Epoch 2/50   -   loss: 0.03625   -   val_loss: 0.02437
# Epoch 3/50   -   loss: 0.02306   -   val_loss: 0.02070
# Epoch 4/50   -   loss: 0.02047   -   val_loss: 0.01894
# Epoch 5/50   -   loss: 0.01875   -   val_loss: 0.01771
# Epoch 6/50   -   loss: 0.01821   -   val_loss: 0.01755
# Epoch 7/50   -   loss: 0.01741   -   val_loss: 0.01693
# Epoch 8/50   -   loss: 0.01706   -   val_loss: 0.01654
# Epoch 9/50   -   loss: 0.01647   -   val_loss: 0.01604
# Epoch 10/50   -   loss: 0.01633   -   val_loss: 0.01610
# Epoch 11/50   -   loss: 0.01590   -   val_loss: 0.01586
# Epoch 12/50   -   loss: 0.01567   -   val_loss: 0.01560
# Epoch 13/50   -   loss: 0.01571   -   val_loss: 0.01565
# Epoch 14/50   -   loss: 0.01527   -   val_loss: 0.01543
# Epoch 15/50   -   loss: 0.01509   -   val_loss: 0.01532
# Epoch 16/50   -   loss: 0.01492   -   val_loss: 0.01528
# Epoch 17/50   -   loss: 0.01470   -   val_loss: 0.01524
# Epoch 18/50   -   loss: 0.01454   -   val_loss: 0.01533
# Epoch 19/50   -   loss: 0.01442   -   val_loss: 0.01511
# Epoch 20/50   -   loss: 0.01431   -   val_loss: 0.01516
# Epoch 21/50   -   loss: 0.01420   -   val_loss: 0.01508
# Epoch 22/50   -   loss: 0.01402   -   val_loss: 0.01501
# Epoch 23/50   -   loss: 0.01403   -   val_loss: 0.01503
# Epoch 24/50   -   loss: 0.01393   -   val_loss: 0.01504
# Epoch 25/50   -   loss: 0.01375   -   val_loss: 0.01503
# Epoch 26/50   -   loss: 0.01365   -   val_loss: 0.01499
# Epoch 27/50   -   loss: 0.01361   -   val_loss: 0.01522
# Epoch 28/50   -   loss: 0.01358   -   val_loss: 0.01493
# Epoch 29/50   -   loss: 0.01344   -   val_loss: 0.01501
# Epoch 30/50   -   loss: 0.01339   -   val_loss: 0.01509
# Epoch 31/50   -   loss: 0.01341   -   val_loss: 0.01506
# Epoch 32/50   -   loss: 0.01333   -   val_loss: 0.01511
# Epoch    32: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 33/50   -   loss: 0.01253   -   val_loss: 0.01482
# Epoch 34/50   -   loss: 0.01212   -   val_loss: 0.01479
# Epoch 35/50   -   loss: 0.01183   -   val_loss: 0.01476
# Epoch 36/50   -   loss: 0.01160   -   val_loss: 0.01478
# Epoch 37/50   -   loss: 0.01142   -   val_loss: 0.01476
# Epoch 38/50   -   loss: 0.01128   -   val_loss: 0.01473
# Epoch 39/50   -   loss: 0.01108   -   val_loss: 0.01476
# Epoch 40/50   -   loss: 0.01091   -   val_loss: 0.01473
# Epoch 41/50   -   loss: 0.01082   -   val_loss: 0.01476
# Epoch 42/50   -   loss: 0.01061   -   val_loss: 0.01474
# Epoch 43/50   -   loss: 0.01048   -   val_loss: 0.01478
# Epoch 44/50   -   loss: 0.01034   -   val_loss: 0.01484
# Epoch 45/50   -   loss: 0.01016   -   val_loss: 0.01490
# Epoch 46/50   -   loss: 0.01004   -   val_loss: 0.01488
# Epoch 47/50   -   loss: 0.00987   -   val_loss: 0.01483
# Epoch 48/50   -   loss: 0.00981   -   val_loss: 0.01488
# Epoch 49/50   -   loss: 0.00960   -   val_loss: 0.01492
# Epoch 50/50   -   loss: 0.00949   -   val_loss: 0.01492
# Train fold 2
# Epoch 1/50   -   loss: 0.34891   -   val_loss: 0.05284
# Epoch 2/50   -   loss: 0.03746   -   val_loss: 0.02437
# Epoch 3/50   -   loss: 0.02311   -   val_loss: 0.01995
# Epoch 4/50   -   loss: 0.02031   -   val_loss: 0.01864
# Epoch 5/50   -   loss: 0.01922   -   val_loss: 0.01777
# Epoch 6/50   -   loss: 0.01810   -   val_loss: 0.01728
# Epoch 7/50   -   loss: 0.01758   -   val_loss: 0.01680
# Epoch 8/50   -   loss: 0.01708   -   val_loss: 0.01640
# Epoch 9/50   -   loss: 0.01662   -   val_loss: 0.01619
# Epoch 10/50   -   loss: 0.01638   -   val_loss: 0.01598
# Epoch 11/50   -   loss: 0.01600   -   val_loss: 0.01584
# Epoch 12/50   -   loss: 0.01568   -   val_loss: 0.01580
# Epoch 13/50   -   loss: 0.01562   -   val_loss: 0.01552
# Epoch 14/50   -   loss: 0.01530   -   val_loss: 0.01557
# Epoch 15/50   -   loss: 0.01508   -   val_loss: 0.01542
# Epoch 16/50   -   loss: 0.01486   -   val_loss: 0.01532
# Epoch 17/50   -   loss: 0.01470   -   val_loss: 0.01536
# Epoch 18/50   -   loss: 0.01453   -   val_loss: 0.01520
# Epoch 19/50   -   loss: 0.01438   -   val_loss: 0.01521
# Epoch 20/50   -   loss: 0.01421   -   val_loss: 0.01525
# Epoch 21/50   -   loss: 0.01417   -   val_loss: 0.01512
# Epoch 22/50   -   loss: 0.01403   -   val_loss: 0.01519
# Epoch 23/50   -   loss: 0.01386   -   val_loss: 0.01508
# Epoch 24/50   -   loss: 0.01373   -   val_loss: 0.01508
# Epoch 25/50   -   loss: 0.01372   -   val_loss: 0.01513
# Epoch 26/50   -   loss: 0.01370   -   val_loss: 0.01506
# Epoch 27/50   -   loss: 0.01364   -   val_loss: 0.01514
# Epoch 28/50   -   loss: 0.01353   -   val_loss: 0.01514
# Epoch 29/50   -   loss: 0.01346   -   val_loss: 0.01511
# Epoch 30/50   -   loss: 0.01342   -   val_loss: 0.01509
# Epoch    30: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 31/50   -   loss: 0.01257   -   val_loss: 0.01488
# Epoch 32/50   -   loss: 0.01220   -   val_loss: 0.01481
# Epoch 33/50   -   loss: 0.01200   -   val_loss: 0.01476
# Epoch 34/50   -   loss: 0.01174   -   val_loss: 0.01476
# Epoch 35/50   -   loss: 0.01155   -   val_loss: 0.01477
# Epoch 36/50   -   loss: 0.01135   -   val_loss: 0.01479
# Epoch 37/50   -   loss: 0.01119   -   val_loss: 0.01480
# Epoch 38/50   -   loss: 0.01105   -   val_loss: 0.01479
# Epoch 39/50   -   loss: 0.01086   -   val_loss: 0.01483
# Epoch 40/50   -   loss: 0.01070   -   val_loss: 0.01486
# Epoch 41/50   -   loss: 0.01055   -   val_loss: 0.01485
# Epoch 42/50   -   loss: 0.01041   -   val_loss: 0.01486
# Epoch 43/50   -   loss: 0.01027   -   val_loss: 0.01488
# Epoch 44/50   -   loss: 0.01014   -   val_loss: 0.01489
# Epoch 45/50   -   loss: 0.00993   -   val_loss: 0.01497
# Epoch 46/50   -   loss: 0.00979   -   val_loss: 0.01496
# Epoch 47/50   -   loss: 0.00969   -   val_loss: 0.01497
# Epoch 48/50   -   loss: 0.00951   -   val_loss: 0.01499
# Epoch 49/50   -   loss: 0.00941   -   val_loss: 0.01503
# Epoch 50/50   -   loss: 0.00927   -   val_loss: 0.01506
# Train fold 3
# Epoch 1/50   -   loss: 0.34916   -   val_loss: 0.05333
# Epoch 2/50   -   loss: 0.03652   -   val_loss: 0.02453
# Epoch 3/50   -   loss: 0.02282   -   val_loss: 0.02041
# Epoch 4/50   -   loss: 0.02032   -   val_loss: 0.01851
# Epoch 5/50   -   loss: 0.01881   -   val_loss: 0.01782
# Epoch 6/50   -   loss: 0.01811   -   val_loss: 0.01717
# Epoch 7/50   -   loss: 0.01752   -   val_loss: 0.01672
# Epoch 8/50   -   loss: 0.01700   -   val_loss: 0.01628
# Epoch 9/50   -   loss: 0.01656   -   val_loss: 0.01611
# Epoch 10/50   -   loss: 0.01658   -   val_loss: 0.01619
# Epoch 11/50   -   loss: 0.01622   -   val_loss: 0.01588
# Epoch 12/50   -   loss: 0.01573   -   val_loss: 0.01557
# Epoch 13/50   -   loss: 0.01546   -   val_loss: 0.01551
# Epoch 14/50   -   loss: 0.01515   -   val_loss: 0.01529
# Epoch 15/50   -   loss: 0.01494   -   val_loss: 0.01526
# Epoch 16/50   -   loss: 0.01482   -   val_loss: 0.01529
# Epoch 17/50   -   loss: 0.01469   -   val_loss: 0.01522
# Epoch 18/50   -   loss: 0.01451   -   val_loss: 0.01506
# Epoch 19/50   -   loss: 0.01438   -   val_loss: 0.01528
# Epoch 20/50   -   loss: 0.01430   -   val_loss: 0.01502
# Epoch 21/50   -   loss: 0.01414   -   val_loss: 0.01499
# Epoch 22/50   -   loss: 0.01403   -   val_loss: 0.01496
# Epoch 23/50   -   loss: 0.01389   -   val_loss: 0.01497
# Epoch 24/50   -   loss: 0.01383   -   val_loss: 0.01497
# Epoch 25/50   -   loss: 0.01376   -   val_loss: 0.01500
# Epoch 26/50   -   loss: 0.01363   -   val_loss: 0.01495
# Epoch 27/50   -   loss: 0.01363   -   val_loss: 0.01493
# Epoch 28/50   -   loss: 0.01356   -   val_loss: 0.01498
# Epoch 29/50   -   loss: 0.01340   -   val_loss: 0.01508
# Epoch 30/50   -   loss: 0.01338   -   val_loss: 0.01494
# Epoch 31/50   -   loss: 0.01336   -   val_loss: 0.01502
# Epoch    31: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 32/50   -   loss: 0.01255   -   val_loss: 0.01476
# Epoch 33/50   -   loss: 0.01214   -   val_loss: 0.01473
# Epoch 34/50   -   loss: 0.01193   -   val_loss: 0.01468
# Epoch 35/50   -   loss: 0.01164   -   val_loss: 0.01470
# Epoch 36/50   -   loss: 0.01149   -   val_loss: 0.01471
# Epoch 37/50   -   loss: 0.01134   -   val_loss: 0.01471
# Epoch 38/50   -   loss: 0.01112   -   val_loss: 0.01471
# Epoch 39/50   -   loss: 0.01097   -   val_loss: 0.01471
# Epoch 40/50   -   loss: 0.01085   -   val_loss: 0.01476
# Epoch 41/50   -   loss: 0.01067   -   val_loss: 0.01477
# Epoch 42/50   -   loss: 0.01049   -   val_loss: 0.01479
# Epoch 43/50   -   loss: 0.01034   -   val_loss: 0.01477
# Epoch 44/50   -   loss: 0.01020   -   val_loss: 0.01481
# Epoch 45/50   -   loss: 0.01007   -   val_loss: 0.01483
# Epoch 46/50   -   loss: 0.00994   -   val_loss: 0.01483
# Epoch 47/50   -   loss: 0.00978   -   val_loss: 0.01487
# Epoch 48/50   -   loss: 0.00967   -   val_loss: 0.01490
# Epoch 49/50   -   loss: 0.00953   -   val_loss: 0.01492
# Epoch 50/50   -   loss: 0.00933   -   val_loss: 0.01489
# Train fold 4
# Epoch 1/50   -   loss: 0.34893   -   val_loss: 0.05279
# Epoch 2/50   -   loss: 0.03639   -   val_loss: 0.02396
# Epoch 3/50   -   loss: 0.02313   -   val_loss: 0.02001
# Epoch 4/50   -   loss: 0.02024   -   val_loss: 0.01874
# Epoch 5/50   -   loss: 0.01945   -   val_loss: 0.01818
# Epoch 6/50   -   loss: 0.01804   -   val_loss: 0.01739
# Epoch 7/50   -   loss: 0.01754   -   val_loss: 0.01709
# Epoch 8/50   -   loss: 0.01705   -   val_loss: 0.01658
# Epoch 9/50   -   loss: 0.01671   -   val_loss: 0.01660
# Epoch 10/50   -   loss: 0.01667   -   val_loss: 0.01651
# Epoch 11/50   -   loss: 0.01621   -   val_loss: 0.01600
# Epoch 12/50   -   loss: 0.01583   -   val_loss: 0.01575
# Epoch 13/50   -   loss: 0.01551   -   val_loss: 0.01567
# Epoch 14/50   -   loss: 0.01526   -   val_loss: 0.01554
# Epoch 15/50   -   loss: 0.01498   -   val_loss: 0.01549
# Epoch 16/50   -   loss: 0.01483   -   val_loss: 0.01540
# Epoch 17/50   -   loss: 0.01461   -   val_loss: 0.01535
# Epoch 18/50   -   loss: 0.01447   -   val_loss: 0.01525
# Epoch 19/50   -   loss: 0.01437   -   val_loss: 0.01539
# Epoch 20/50   -   loss: 0.01427   -   val_loss: 0.01529
# Epoch 21/50   -   loss: 0.01403   -   val_loss: 0.01528
# Epoch 22/50   -   loss: 0.01398   -   val_loss: 0.01532
# Epoch    22: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 23/50   -   loss: 0.01324   -   val_loss: 0.01502
# Epoch 24/50   -   loss: 0.01290   -   val_loss: 0.01495
# Epoch 25/50   -   loss: 0.01268   -   val_loss: 0.01495
# Epoch 26/50   -   loss: 0.01243   -   val_loss: 0.01489
# Epoch 27/50   -   loss: 0.01227   -   val_loss: 0.01492
# Epoch 28/50   -   loss: 0.01215   -   val_loss: 0.01490
# Epoch 29/50   -   loss: 0.01198   -   val_loss: 0.01492
# Epoch 30/50   -   loss: 0.01181   -   val_loss: 0.01493
# Epoch 31/50   -   loss: 0.01162   -   val_loss: 0.01492
# Epoch 32/50   -   loss: 0.01147   -   val_loss: 0.01492
# Epoch 33/50   -   loss: 0.01128   -   val_loss: 0.01494
# Epoch 34/50   -   loss: 0.01115   -   val_loss: 0.01502
# Epoch 35/50   -   loss: 0.01096   -   val_loss: 0.01500
# Epoch 36/50   -   loss: 0.01083   -   val_loss: 0.01496
# Epoch 37/50   -   loss: 0.01069   -   val_loss: 0.01496
# Epoch 38/50   -   loss: 0.01049   -   val_loss: 0.01499
# Epoch 39/50   -   loss: 0.01032   -   val_loss: 0.01499
# Epoch 40/50   -   loss: 0.01014   -   val_loss: 0.01507
# Epoch 41/50   -   loss: 0.01003   -   val_loss: 0.01511
# Epoch 42/50   -   loss: 0.00989   -   val_loss: 0.01508
# Epoch 43/50   -   loss: 0.00970   -   val_loss: 0.01514
# Epoch 44/50   -   loss: 0.00955   -   val_loss: 0.01516
# Epoch 45/50   -   loss: 0.00938   -   val_loss: 0.01518
# Epoch 46/50   -   loss: 0.00927   -   val_loss: 0.01516
# Epoch 47/50   -   loss: 0.00908   -   val_loss: 0.01518
# Epoch 48/50   -   loss: 0.00891   -   val_loss: 0.01523
# Epoch 49/50   -   loss: 0.00881   -   val_loss: 0.01528
# Epoch 50/50   -   loss: 0.00867   -   val_loss: 0.01528
# Train fold 5
# Epoch 1/50   -   loss: 0.34862   -   val_loss: 0.05246
# Epoch 2/50   -   loss: 0.03686   -   val_loss: 0.02483
# Epoch 3/50   -   loss: 0.02330   -   val_loss: 0.02009
# Epoch 4/50   -   loss: 0.02022   -   val_loss: 0.01840
# Epoch 5/50   -   loss: 0.01898   -   val_loss: 0.01839
# Epoch 6/50   -   loss: 0.01820   -   val_loss: 0.01706
# Epoch 7/50   -   loss: 0.01738   -   val_loss: 0.01659
# Epoch 8/50   -   loss: 0.01702   -   val_loss: 0.01652
# Epoch 9/50   -   loss: 0.01667   -   val_loss: 0.01610
# Epoch 10/50   -   loss: 0.01644   -   val_loss: 0.01622
# Epoch 11/50   -   loss: 0.01616   -   val_loss: 0.01585
# Epoch 12/50   -   loss: 0.01587   -   val_loss: 0.01587
# Epoch 13/50   -   loss: 0.01557   -   val_loss: 0.01546
# Epoch 14/50   -   loss: 0.01530   -   val_loss: 0.01535
# Epoch 15/50   -   loss: 0.01506   -   val_loss: 0.01537
# Epoch 16/50   -   loss: 0.01490   -   val_loss: 0.01532
# Epoch 17/50   -   loss: 0.01472   -   val_loss: 0.01523
# Epoch 18/50   -   loss: 0.01448   -   val_loss: 0.01511
# Epoch 19/50   -   loss: 0.01439   -   val_loss: 0.01509
# Epoch 20/50   -   loss: 0.01426   -   val_loss: 0.01502
# Epoch 21/50   -   loss: 0.01419   -   val_loss: 0.01497
# Epoch 22/50   -   loss: 0.01407   -   val_loss: 0.01503
# Epoch 23/50   -   loss: 0.01392   -   val_loss: 0.01505
# Epoch 24/50   -   loss: 0.01396   -   val_loss: 0.01511
# Epoch 25/50   -   loss: 0.01376   -   val_loss: 0.01511
# Epoch    25: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 26/50   -   loss: 0.01297   -   val_loss: 0.01478
# Epoch 27/50   -   loss: 0.01263   -   val_loss: 0.01471
# Epoch 28/50   -   loss: 0.01241   -   val_loss: 0.01469
# Epoch 29/50   -   loss: 0.01216   -   val_loss: 0.01466
# Epoch 30/50   -   loss: 0.01199   -   val_loss: 0.01464
# Epoch 31/50   -   loss: 0.01189   -   val_loss: 0.01463
# Epoch 32/50   -   loss: 0.01168   -   val_loss: 0.01465
# Epoch 33/50   -   loss: 0.01157   -   val_loss: 0.01468
# Epoch 34/50   -   loss: 0.01139   -   val_loss: 0.01468
# Epoch 35/50   -   loss: 0.01121   -   val_loss: 0.01467
# Epoch 36/50   -   loss: 0.01111   -   val_loss: 0.01469
# Epoch 37/50   -   loss: 0.01090   -   val_loss: 0.01469
# Epoch 38/50   -   loss: 0.01082   -   val_loss: 0.01471
# Epoch 39/50   -   loss: 0.01061   -   val_loss: 0.01474
# Epoch 40/50   -   loss: 0.01047   -   val_loss: 0.01472
# Epoch 41/50   -   loss: 0.01031   -   val_loss: 0.01474
# Epoch 42/50   -   loss: 0.01019   -   val_loss: 0.01481
# Epoch 43/50   -   loss: 0.01007   -   val_loss: 0.01481
# Epoch 44/50   -   loss: 0.00992   -   val_loss: 0.01478
# Epoch 45/50   -   loss: 0.00976   -   val_loss: 0.01477
# Epoch 46/50   -   loss: 0.00960   -   val_loss: 0.01486
# Epoch 47/50   -   loss: 0.00944   -   val_loss: 0.01490
# Epoch 48/50   -   loss: 0.00929   -   val_loss: 0.01487
# Epoch 49/50   -   loss: 0.00913   -   val_loss: 0.01493
# Epoch 50/50   -   loss: 0.00901   -   val_loss: 0.01498
# Train fold 6
# Epoch 1/50   -   loss: 0.34827   -   val_loss: 0.05455
# Epoch 2/50   -   loss: 0.03620   -   val_loss: 0.02297
# Epoch 3/50   -   loss: 0.02317   -   val_loss: 0.02005
# Epoch 4/50   -   loss: 0.02036   -   val_loss: 0.01830
# Epoch 5/50   -   loss: 0.01911   -   val_loss: 0.01829
# Epoch 6/50   -   loss: 0.01827   -   val_loss: 0.01694
# Epoch 7/50   -   loss: 0.01763   -   val_loss: 0.01673
# Epoch 8/50   -   loss: 0.01705   -   val_loss: 0.01622
# Epoch 9/50   -   loss: 0.01676   -   val_loss: 0.01591
# Epoch 10/50   -   loss: 0.01630   -   val_loss: 0.01568
# Epoch 11/50   -   loss: 0.01603   -   val_loss: 0.01559
# Epoch 12/50   -   loss: 0.01574   -   val_loss: 0.01531
# Epoch 13/50   -   loss: 0.01547   -   val_loss: 0.01526
# Epoch 14/50   -   loss: 0.01520   -   val_loss: 0.01520
# Epoch 15/50   -   loss: 0.01509   -   val_loss: 0.01519
# Epoch 16/50   -   loss: 0.01494   -   val_loss: 0.01500
# Epoch 17/50   -   loss: 0.01479   -   val_loss: 0.01503
# Epoch 18/50   -   loss: 0.01456   -   val_loss: 0.01494
# Epoch 19/50   -   loss: 0.01435   -   val_loss: 0.01495
# Epoch 20/50   -   loss: 0.01430   -   val_loss: 0.01488
# Epoch 21/50   -   loss: 0.01421   -   val_loss: 0.01491
# Epoch 22/50   -   loss: 0.01410   -   val_loss: 0.01482
# Epoch 23/50   -   loss: 0.01397   -   val_loss: 0.01482
# Epoch 24/50   -   loss: 0.01381   -   val_loss: 0.01487
# Epoch 25/50   -   loss: 0.01370   -   val_loss: 0.01488
# Epoch 26/50   -   loss: 0.01370   -   val_loss: 0.01489
# Epoch 27/50   -   loss: 0.01361   -   val_loss: 0.01476
# Epoch 28/50   -   loss: 0.01352   -   val_loss: 0.01479
# Epoch 29/50   -   loss: 0.01341   -   val_loss: 0.01476
# Epoch 30/50   -   loss: 0.01345   -   val_loss: 0.01476
# Epoch 31/50   -   loss: 0.01336   -   val_loss: 0.01481
# Epoch 32/50   -   loss: 0.01332   -   val_loss: 0.01486
# Epoch 33/50   -   loss: 0.01327   -   val_loss: 0.01492
# Epoch 34/50   -   loss: 0.01315   -   val_loss: 0.01482
# Epoch    34: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 35/50   -   loss: 0.01233   -   val_loss: 0.01466
# Epoch 36/50   -   loss: 0.01192   -   val_loss: 0.01461
# Epoch 37/50   -   loss: 0.01160   -   val_loss: 0.01460
# Epoch 38/50   -   loss: 0.01146   -   val_loss: 0.01460
# Epoch 39/50   -   loss: 0.01127   -   val_loss: 0.01459
# Epoch 40/50   -   loss: 0.01102   -   val_loss: 0.01461
# Epoch 41/50   -   loss: 0.01087   -   val_loss: 0.01460
# Epoch 42/50   -   loss: 0.01074   -   val_loss: 0.01461
# Epoch 43/50   -   loss: 0.01059   -   val_loss: 0.01459
# Epoch 44/50   -   loss: 0.01041   -   val_loss: 0.01461
# Epoch 45/50   -   loss: 0.01024   -   val_loss: 0.01462
# Epoch 46/50   -   loss: 0.01012   -   val_loss: 0.01465
# Epoch 47/50   -   loss: 0.00997   -   val_loss: 0.01465
# Epoch 48/50   -   loss: 0.00984   -   val_loss: 0.01464
# Epoch 49/50   -   loss: 0.00971   -   val_loss: 0.01470
# Epoch 50/50   -   loss: 0.00954   -   val_loss: 0.01470
# {'train': 0.011270263120296256, 'val': 0.01458931085653603}

# %%
run_eval_for_model(Model2, 2, train_X0, train_Y0, test_X0)
# Out:
# Overall score is 0.01089

# %%
class Model3(nn.Module):
    def __init__(self, num_columns):
        super(Model3, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_columns)
        self.dropout1 = nn.Dropout(0.2)
        self.dense1 = nn.utils.weight_norm(nn.Linear(num_columns, 2048))
        
        self.batch_norm2 = nn.BatchNorm1d(2048)
        self.dropout2 = nn.Dropout(0.5)
        self.dense2 = nn.utils.weight_norm(nn.Linear(2048, 1024))
        
        self.batch_norm3 = nn.BatchNorm1d(1024)
        self.dropout3 = nn.Dropout(0.5)
        self.dense3 = nn.utils.weight_norm(nn.Linear(1024, 206))
    
    def forward(self, x):
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        x = F.leaky_relu(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = F.leaky_relu(self.dense2(x))
        
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x = F.sigmoid(self.dense3(x))
        
        return x

# %%
run_CV_for_model(Model3, 3, train_X2, train_Y2, test_X2)
# Out:
# Train fold 1
# Epoch 1/50   -   loss: 0.34673   -   val_loss: 0.05585
# Epoch 2/50   -   loss: 0.03659   -   val_loss: 0.02352
# Epoch 3/50   -   loss: 0.02339   -   val_loss: 0.02030
# Epoch 4/50   -   loss: 0.02027   -   val_loss: 0.01888
# Epoch 5/50   -   loss: 0.01885   -   val_loss: 0.01794
# Epoch 6/50   -   loss: 0.01815   -   val_loss: 0.01756
# Epoch 7/50   -   loss: 0.01761   -   val_loss: 0.01688
# Epoch 8/50   -   loss: 0.01708   -   val_loss: 0.01651
# Epoch 9/50   -   loss: 0.01672   -   val_loss: 0.01621
# Epoch 10/50   -   loss: 0.01629   -   val_loss: 0.01594
# Epoch 11/50   -   loss: 0.01594   -   val_loss: 0.01593
# Epoch 12/50   -   loss: 0.01574   -   val_loss: 0.01574
# Epoch 13/50   -   loss: 0.01554   -   val_loss: 0.01575
# Epoch 14/50   -   loss: 0.01533   -   val_loss: 0.01558
# Epoch 15/50   -   loss: 0.01509   -   val_loss: 0.01538
# Epoch 16/50   -   loss: 0.01483   -   val_loss: 0.01523
# Epoch 17/50   -   loss: 0.01466   -   val_loss: 0.01518
# Epoch 18/50   -   loss: 0.01461   -   val_loss: 0.01539
# Epoch 19/50   -   loss: 0.01445   -   val_loss: 0.01517
# Epoch 20/50   -   loss: 0.01421   -   val_loss: 0.01520
# Epoch 21/50   -   loss: 0.01421   -   val_loss: 0.01510
# Epoch 22/50   -   loss: 0.01405   -   val_loss: 0.01516
# Epoch 23/50   -   loss: 0.01403   -   val_loss: 0.01505
# Epoch 24/50   -   loss: 0.01388   -   val_loss: 0.01506
# Epoch 25/50   -   loss: 0.01381   -   val_loss: 0.01521
# Epoch 26/50   -   loss: 0.01367   -   val_loss: 0.01503
# Epoch 27/50   -   loss: 0.01360   -   val_loss: 0.01525
# Epoch 28/50   -   loss: 0.01358   -   val_loss: 0.01498
# Epoch 29/50   -   loss: 0.01346   -   val_loss: 0.01509
# Epoch 30/50   -   loss: 0.01344   -   val_loss: 0.01502
# Epoch 31/50   -   loss: 0.01338   -   val_loss: 0.01505
# Epoch 32/50   -   loss: 0.01335   -   val_loss: 0.01507
# Epoch    32: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 33/50   -   loss: 0.01252   -   val_loss: 0.01481
# Epoch 34/50   -   loss: 0.01208   -   val_loss: 0.01480
# Epoch 35/50   -   loss: 0.01181   -   val_loss: 0.01480
# Epoch 36/50   -   loss: 0.01161   -   val_loss: 0.01480
# Epoch 37/50   -   loss: 0.01139   -   val_loss: 0.01480
# Epoch 38/50   -   loss: 0.01119   -   val_loss: 0.01478
# Epoch 39/50   -   loss: 0.01106   -   val_loss: 0.01481
# Epoch 40/50   -   loss: 0.01091   -   val_loss: 0.01478
# Epoch 41/50   -   loss: 0.01069   -   val_loss: 0.01483
# Epoch 42/50   -   loss: 0.01055   -   val_loss: 0.01484
# Epoch 43/50   -   loss: 0.01040   -   val_loss: 0.01486
# Epoch 44/50   -   loss: 0.01026   -   val_loss: 0.01487
# Epoch 45/50   -   loss: 0.01010   -   val_loss: 0.01492
# Epoch 46/50   -   loss: 0.00991   -   val_loss: 0.01490
# Epoch 47/50   -   loss: 0.00981   -   val_loss: 0.01488
# Epoch 48/50   -   loss: 0.00968   -   val_loss: 0.01491
# Epoch 49/50   -   loss: 0.00952   -   val_loss: 0.01495
# Epoch 50/50   -   loss: 0.00937   -   val_loss: 0.01498
# Train fold 2
# Epoch 1/50   -   loss: 0.34770   -   val_loss: 0.05371
# Epoch 2/50   -   loss: 0.03684   -   val_loss: 0.02418
# Epoch 3/50   -   loss: 0.02356   -   val_loss: 0.02062
# Epoch 4/50   -   loss: 0.02030   -   val_loss: 0.01871
# Epoch 5/50   -   loss: 0.01935   -   val_loss: 0.01789
# Epoch 6/50   -   loss: 0.01823   -   val_loss: 0.01746
# Epoch 7/50   -   loss: 0.01755   -   val_loss: 0.01672
# Epoch 8/50   -   loss: 0.01717   -   val_loss: 0.01670
# Epoch 9/50   -   loss: 0.01672   -   val_loss: 0.01616
# Epoch 10/50   -   loss: 0.01636   -   val_loss: 0.01601
# Epoch 11/50   -   loss: 0.01626   -   val_loss: 0.01591
# Epoch 12/50   -   loss: 0.01574   -   val_loss: 0.01574
# Epoch 13/50   -   loss: 0.01552   -   val_loss: 0.01551
# Epoch 14/50   -   loss: 0.01517   -   val_loss: 0.01548
# Epoch 15/50   -   loss: 0.01503   -   val_loss: 0.01544
# Epoch 16/50   -   loss: 0.01489   -   val_loss: 0.01533
# Epoch 17/50   -   loss: 0.01464   -   val_loss: 0.01529
# Epoch 18/50   -   loss: 0.01457   -   val_loss: 0.01521
# Epoch 19/50   -   loss: 0.01439   -   val_loss: 0.01530
# Epoch 20/50   -   loss: 0.01427   -   val_loss: 0.01518
# Epoch 21/50   -   loss: 0.01419   -   val_loss: 0.01510
# Epoch 22/50   -   loss: 0.01405   -   val_loss: 0.01513
# Epoch 23/50   -   loss: 0.01386   -   val_loss: 0.01511
# Epoch 24/50   -   loss: 0.01377   -   val_loss: 0.01523
# Epoch 25/50   -   loss: 0.01368   -   val_loss: 0.01513
# Epoch    25: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 26/50   -   loss: 0.01294   -   val_loss: 0.01487
# Epoch 27/50   -   loss: 0.01260   -   val_loss: 0.01481
# Epoch 28/50   -   loss: 0.01228   -   val_loss: 0.01486
# Epoch 29/50   -   loss: 0.01213   -   val_loss: 0.01480
# Epoch 30/50   -   loss: 0.01198   -   val_loss: 0.01481
# Epoch 31/50   -   loss: 0.01176   -   val_loss: 0.01482
# Epoch 32/50   -   loss: 0.01159   -   val_loss: 0.01481
# Epoch 33/50   -   loss: 0.01148   -   val_loss: 0.01479
# Epoch 34/50   -   loss: 0.01127   -   val_loss: 0.01480
# Epoch 35/50   -   loss: 0.01112   -   val_loss: 0.01481
# Epoch 36/50   -   loss: 0.01095   -   val_loss: 0.01482
# Epoch 37/50   -   loss: 0.01079   -   val_loss: 0.01487
# Epoch 38/50   -   loss: 0.01065   -   val_loss: 0.01488
# Epoch 39/50   -   loss: 0.01044   -   val_loss: 0.01492
# Epoch 40/50   -   loss: 0.01032   -   val_loss: 0.01494
# Epoch 41/50   -   loss: 0.01014   -   val_loss: 0.01492
# Epoch 42/50   -   loss: 0.01007   -   val_loss: 0.01495
# Epoch 43/50   -   loss: 0.00984   -   val_loss: 0.01498
# Epoch 44/50   -   loss: 0.00968   -   val_loss: 0.01501
# Epoch 45/50   -   loss: 0.00956   -   val_loss: 0.01505
# Epoch 46/50   -   loss: 0.00936   -   val_loss: 0.01510
# Epoch 47/50   -   loss: 0.00921   -   val_loss: 0.01512
# Epoch 48/50   -   loss: 0.00907   -   val_loss: 0.01513
# Epoch 49/50   -   loss: 0.00895   -   val_loss: 0.01517
# Epoch 50/50   -   loss: 0.00878   -   val_loss: 0.01524
# Train fold 3
# Epoch 1/50   -   loss: 0.34963   -   val_loss: 0.05525
# Epoch 2/50   -   loss: 0.03607   -   val_loss: 0.02613
# Epoch 3/50   -   loss: 0.02323   -   val_loss: 0.02113
# Epoch 4/50   -   loss: 0.02065   -   val_loss: 0.01873
# Epoch 5/50   -   loss: 0.01880   -   val_loss: 0.01771
# Epoch 6/50   -   loss: 0.01801   -   val_loss: 0.01709
# Epoch 7/50   -   loss: 0.01745   -   val_loss: 0.01673
# Epoch 8/50   -   loss: 0.01693   -   val_loss: 0.01621
# Epoch 9/50   -   loss: 0.01657   -   val_loss: 0.01605
# Epoch 10/50   -   loss: 0.01622   -   val_loss: 0.01604
# Epoch 11/50   -   loss: 0.01593   -   val_loss: 0.01574
# Epoch 12/50   -   loss: 0.01566   -   val_loss: 0.01564
# Epoch 13/50   -   loss: 0.01549   -   val_loss: 0.01561
# Epoch 14/50   -   loss: 0.01529   -   val_loss: 0.01531
# Epoch 15/50   -   loss: 0.01498   -   val_loss: 0.01527
# Epoch 16/50   -   loss: 0.01486   -   val_loss: 0.01524
# Epoch 17/50   -   loss: 0.01473   -   val_loss: 0.01525
# Epoch 18/50   -   loss: 0.01456   -   val_loss: 0.01514
# Epoch 19/50   -   loss: 0.01442   -   val_loss: 0.01510
# Epoch 20/50   -   loss: 0.01428   -   val_loss: 0.01506
# Epoch 21/50   -   loss: 0.01418   -   val_loss: 0.01509
# Epoch 22/50   -   loss: 0.01408   -   val_loss: 0.01508
# Epoch 23/50   -   loss: 0.01392   -   val_loss: 0.01497
# Epoch 24/50   -   loss: 0.01393   -   val_loss: 0.01507
# Epoch 25/50   -   loss: 0.01382   -   val_loss: 0.01513
# Epoch 26/50   -   loss: 0.01368   -   val_loss: 0.01501
# Epoch 27/50   -   loss: 0.01364   -   val_loss: 0.01497
# Epoch 28/50   -   loss: 0.01355   -   val_loss: 0.01499
# Epoch 29/50   -   loss: 0.01353   -   val_loss: 0.01498
# Epoch 30/50   -   loss: 0.01346   -   val_loss: 0.01503
# Epoch 31/50   -   loss: 0.01340   -   val_loss: 0.01498
# Epoch    31: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 32/50   -   loss: 0.01258   -   val_loss: 0.01477
# Epoch 33/50   -   loss: 0.01218   -   val_loss: 0.01475
# Epoch 34/50   -   loss: 0.01197   -   val_loss: 0.01475
# Epoch 35/50   -   loss: 0.01172   -   val_loss: 0.01475
# Epoch 36/50   -   loss: 0.01155   -   val_loss: 0.01473
# Epoch 37/50   -   loss: 0.01132   -   val_loss: 0.01477
# Epoch 38/50   -   loss: 0.01118   -   val_loss: 0.01476
# Epoch 39/50   -   loss: 0.01104   -   val_loss: 0.01475
# Epoch 40/50   -   loss: 0.01087   -   val_loss: 0.01481
# Epoch 41/50   -   loss: 0.01071   -   val_loss: 0.01481
# Epoch 42/50   -   loss: 0.01058   -   val_loss: 0.01481
# Epoch 43/50   -   loss: 0.01040   -   val_loss: 0.01483
# Epoch 44/50   -   loss: 0.01027   -   val_loss: 0.01486
# Epoch 45/50   -   loss: 0.01010   -   val_loss: 0.01488
# Epoch 46/50   -   loss: 0.00994   -   val_loss: 0.01488
# Epoch 47/50   -   loss: 0.00983   -   val_loss: 0.01491
# Epoch 48/50   -   loss: 0.00969   -   val_loss: 0.01494
# Epoch 49/50   -   loss: 0.00953   -   val_loss: 0.01497
# Epoch 50/50   -   loss: 0.00939   -   val_loss: 0.01493
# Train fold 4
# Epoch 1/50   -   loss: 0.34887   -   val_loss: 0.05303
# Epoch 2/50   -   loss: 0.03643   -   val_loss: 0.02413
# Epoch 3/50   -   loss: 0.02307   -   val_loss: 0.02017
# Epoch 4/50   -   loss: 0.02028   -   val_loss: 0.01868
# Epoch 5/50   -   loss: 0.01901   -   val_loss: 0.01850
# Epoch 6/50   -   loss: 0.01810   -   val_loss: 0.01757
# Epoch 7/50   -   loss: 0.01758   -   val_loss: 0.01684
# Epoch 8/50   -   loss: 0.01707   -   val_loss: 0.01662
# Epoch 9/50   -   loss: 0.01653   -   val_loss: 0.01634
# Epoch 10/50   -   loss: 0.01627   -   val_loss: 0.01611
# Epoch 11/50   -   loss: 0.01594   -   val_loss: 0.01593
# Epoch 12/50   -   loss: 0.01575   -   val_loss: 0.01584
# Epoch 13/50   -   loss: 0.01535   -   val_loss: 0.01569
# Epoch 14/50   -   loss: 0.01515   -   val_loss: 0.01557
# Epoch 15/50   -   loss: 0.01495   -   val_loss: 0.01553
# Epoch 16/50   -   loss: 0.01477   -   val_loss: 0.01543
# Epoch 17/50   -   loss: 0.01454   -   val_loss: 0.01537
# Epoch 18/50   -   loss: 0.01443   -   val_loss: 0.01533
# Epoch 19/50   -   loss: 0.01431   -   val_loss: 0.01545
# Epoch 20/50   -   loss: 0.01422   -   val_loss: 0.01531
# Epoch 21/50   -   loss: 0.01404   -   val_loss: 0.01522
# Epoch 22/50   -   loss: 0.01394   -   val_loss: 0.01527
# Epoch 23/50   -   loss: 0.01385   -   val_loss: 0.01520
# Epoch 24/50   -   loss: 0.01378   -   val_loss: 0.01525
# Epoch 25/50   -   loss: 0.01369   -   val_loss: 0.01516
# Epoch 26/50   -   loss: 0.01356   -   val_loss: 0.01530
# Epoch 27/50   -   loss: 0.01356   -   val_loss: 0.01525
# Epoch 28/50   -   loss: 0.01351   -   val_loss: 0.01511
# Epoch 29/50   -   loss: 0.01342   -   val_loss: 0.01529
# Epoch 30/50   -   loss: 0.01336   -   val_loss: 0.01540
# Epoch 31/50   -   loss: 0.01332   -   val_loss: 0.01559
# Epoch 32/50   -   loss: 0.01328   -   val_loss: 0.01525
# Epoch    32: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 33/50   -   loss: 0.01241   -   val_loss: 0.01500
# Epoch 34/50   -   loss: 0.01206   -   val_loss: 0.01502
# Epoch 35/50   -   loss: 0.01179   -   val_loss: 0.01496
# Epoch 36/50   -   loss: 0.01156   -   val_loss: 0.01493
# Epoch 37/50   -   loss: 0.01134   -   val_loss: 0.01492
# Epoch 38/50   -   loss: 0.01119   -   val_loss: 0.01493
# Epoch 39/50   -   loss: 0.01096   -   val_loss: 0.01492
# Epoch 40/50   -   loss: 0.01087   -   val_loss: 0.01500
# Epoch 41/50   -   loss: 0.01068   -   val_loss: 0.01501
# Epoch 42/50   -   loss: 0.01056   -   val_loss: 0.01500
# Epoch 43/50   -   loss: 0.01039   -   val_loss: 0.01503
# Epoch 44/50   -   loss: 0.01022   -   val_loss: 0.01507
# Epoch 45/50   -   loss: 0.01008   -   val_loss: 0.01503
# Epoch 46/50   -   loss: 0.00991   -   val_loss: 0.01504
# Epoch 47/50   -   loss: 0.00975   -   val_loss: 0.01506
# Epoch 48/50   -   loss: 0.00964   -   val_loss: 0.01503
# Epoch 49/50   -   loss: 0.00946   -   val_loss: 0.01511
# Epoch 50/50   -   loss: 0.00934   -   val_loss: 0.01514
# Train fold 5
# Epoch 1/50   -   loss: 0.34870   -   val_loss: 0.05478
# Epoch 2/50   -   loss: 0.03671   -   val_loss: 0.02367
# Epoch 3/50   -   loss: 0.02323   -   val_loss: 0.01997
# Epoch 4/50   -   loss: 0.02033   -   val_loss: 0.01868
# Epoch 5/50   -   loss: 0.01912   -   val_loss: 0.01835
# Epoch 6/50   -   loss: 0.01834   -   val_loss: 0.01725
# Epoch 7/50   -   loss: 0.01747   -   val_loss: 0.01668
# Epoch 8/50   -   loss: 0.01702   -   val_loss: 0.01649
# Epoch 9/50   -   loss: 0.01669   -   val_loss: 0.01623
# Epoch 10/50   -   loss: 0.01632   -   val_loss: 0.01593
# Epoch 11/50   -   loss: 0.01602   -   val_loss: 0.01580
# Epoch 12/50   -   loss: 0.01577   -   val_loss: 0.01569
# Epoch 13/50   -   loss: 0.01563   -   val_loss: 0.01552
# Epoch 14/50   -   loss: 0.01524   -   val_loss: 0.01528
# Epoch 15/50   -   loss: 0.01503   -   val_loss: 0.01544
# Epoch 16/50   -   loss: 0.01481   -   val_loss: 0.01533
# Epoch 17/50   -   loss: 0.01470   -   val_loss: 0.01518
# Epoch 18/50   -   loss: 0.01448   -   val_loss: 0.01514
# Epoch 19/50   -   loss: 0.01449   -   val_loss: 0.01513
# Epoch 20/50   -   loss: 0.01427   -   val_loss: 0.01511
# Epoch 21/50   -   loss: 0.01412   -   val_loss: 0.01501
# Epoch 22/50   -   loss: 0.01400   -   val_loss: 0.01504
# Epoch 23/50   -   loss: 0.01397   -   val_loss: 0.01504
# Epoch 24/50   -   loss: 0.01387   -   val_loss: 0.01508
# Epoch 25/50   -   loss: 0.01376   -   val_loss: 0.01509
# Epoch    25: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 26/50   -   loss: 0.01296   -   val_loss: 0.01477
# Epoch 27/50   -   loss: 0.01263   -   val_loss: 0.01469
# Epoch 28/50   -   loss: 0.01242   -   val_loss: 0.01467
# Epoch 29/50   -   loss: 0.01213   -   val_loss: 0.01464
# Epoch 30/50   -   loss: 0.01198   -   val_loss: 0.01464
# Epoch 31/50   -   loss: 0.01184   -   val_loss: 0.01461
# Epoch 32/50   -   loss: 0.01160   -   val_loss: 0.01465
# Epoch 33/50   -   loss: 0.01151   -   val_loss: 0.01469
# Epoch 34/50   -   loss: 0.01136   -   val_loss: 0.01466
# Epoch 35/50   -   loss: 0.01118   -   val_loss: 0.01466
# Epoch 36/50   -   loss: 0.01101   -   val_loss: 0.01465
# Epoch 37/50   -   loss: 0.01078   -   val_loss: 0.01467
# Epoch 38/50   -   loss: 0.01072   -   val_loss: 0.01469
# Epoch 39/50   -   loss: 0.01054   -   val_loss: 0.01470
# Epoch 40/50   -   loss: 0.01037   -   val_loss: 0.01472
# Epoch 41/50   -   loss: 0.01024   -   val_loss: 0.01473
# Epoch 42/50   -   loss: 0.01008   -   val_loss: 0.01482
# Epoch 43/50   -   loss: 0.00990   -   val_loss: 0.01482
# Epoch 44/50   -   loss: 0.00978   -   val_loss: 0.01479
# Epoch 45/50   -   loss: 0.00960   -   val_loss: 0.01481
# Epoch 46/50   -   loss: 0.00946   -   val_loss: 0.01486
# Epoch 47/50   -   loss: 0.00927   -   val_loss: 0.01488
# Epoch 48/50   -   loss: 0.00910   -   val_loss: 0.01488
# Epoch 49/50   -   loss: 0.00894   -   val_loss: 0.01495
# Epoch 50/50   -   loss: 0.00882   -   val_loss: 0.01500
# Train fold 6
# Epoch 1/50   -   loss: 0.34774   -   val_loss: 0.05118
# Epoch 2/50   -   loss: 0.03594   -   val_loss: 0.02304
# Epoch 3/50   -   loss: 0.02362   -   val_loss: 0.02010
# Epoch 4/50   -   loss: 0.02059   -   val_loss: 0.01848
# Epoch 5/50   -   loss: 0.01903   -   val_loss: 0.01758
# Epoch 6/50   -   loss: 0.01835   -   val_loss: 0.01716
# Epoch 7/50   -   loss: 0.01756   -   val_loss: 0.01675
# Epoch 8/50   -   loss: 0.01707   -   val_loss: 0.01640
# Epoch 9/50   -   loss: 0.01666   -   val_loss: 0.01589
# Epoch 10/50   -   loss: 0.01633   -   val_loss: 0.01567
# Epoch 11/50   -   loss: 0.01634   -   val_loss: 0.01579
# Epoch 12/50   -   loss: 0.01589   -   val_loss: 0.01537
# Epoch 13/50   -   loss: 0.01558   -   val_loss: 0.01539
# Epoch 14/50   -   loss: 0.01533   -   val_loss: 0.01521
# Epoch 15/50   -   loss: 0.01513   -   val_loss: 0.01515
# Epoch 16/50   -   loss: 0.01494   -   val_loss: 0.01504
# Epoch 17/50   -   loss: 0.01481   -   val_loss: 0.01498
# Epoch 18/50   -   loss: 0.01453   -   val_loss: 0.01499
# Epoch 19/50   -   loss: 0.01439   -   val_loss: 0.01498
# Epoch 20/50   -   loss: 0.01432   -   val_loss: 0.01493
# Epoch 21/50   -   loss: 0.01426   -   val_loss: 0.01488
# Epoch 22/50   -   loss: 0.01416   -   val_loss: 0.01489
# Epoch 23/50   -   loss: 0.01398   -   val_loss: 0.01482
# Epoch 24/50   -   loss: 0.01384   -   val_loss: 0.01481
# Epoch 25/50   -   loss: 0.01380   -   val_loss: 0.01491
# Epoch 26/50   -   loss: 0.01371   -   val_loss: 0.01482
# Epoch 27/50   -   loss: 0.01374   -   val_loss: 0.01472
# Epoch 28/50   -   loss: 0.01363   -   val_loss: 0.01480
# Epoch 29/50   -   loss: 0.01349   -   val_loss: 0.01476
# Epoch 30/50   -   loss: 0.01352   -   val_loss: 0.01475
# Epoch 31/50   -   loss: 0.01341   -   val_loss: 0.01487
# Epoch    31: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 32/50   -   loss: 0.01267   -   val_loss: 0.01460
# Epoch 33/50   -   loss: 0.01225   -   val_loss: 0.01454
# Epoch 34/50   -   loss: 0.01198   -   val_loss: 0.01450
# Epoch 35/50   -   loss: 0.01174   -   val_loss: 0.01449
# Epoch 36/50   -   loss: 0.01157   -   val_loss: 0.01450
# Epoch 37/50   -   loss: 0.01137   -   val_loss: 0.01448
# Epoch 38/50   -   loss: 0.01123   -   val_loss: 0.01451
# Epoch 39/50   -   loss: 0.01105   -   val_loss: 0.01449
# Epoch 40/50   -   loss: 0.01088   -   val_loss: 0.01455
# Epoch 41/50   -   loss: 0.01073   -   val_loss: 0.01451
# Epoch 42/50   -   loss: 0.01065   -   val_loss: 0.01455
# Epoch 43/50   -   loss: 0.01046   -   val_loss: 0.01453
# Epoch 44/50   -   loss: 0.01034   -   val_loss: 0.01454
# Epoch 45/50   -   loss: 0.01015   -   val_loss: 0.01454
# Epoch 46/50   -   loss: 0.01003   -   val_loss: 0.01458
# Epoch 47/50   -   loss: 0.00989   -   val_loss: 0.01459
# Epoch 48/50   -   loss: 0.00972   -   val_loss: 0.01461
# Epoch 49/50   -   loss: 0.00959   -   val_loss: 0.01464
# Epoch 50/50   -   loss: 0.00942   -   val_loss: 0.01465
# {'train': 0.011365584398419412, 'val': 0.014477502671070397}

# %%
run_eval_for_model(Model3, 3, train_X0, train_Y0, test_X0)
# Out:
# Overall score is 0.01051

# %%
class Model4(nn.Module):
    def __init__(self, num_columns):
        super(Model4, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_columns)
        self.dropout1 = nn.Dropout(0.2)
        self.dense1 = nn.utils.weight_norm(nn.Linear(num_columns, 2048))
        
        self.batch_norm2 = nn.BatchNorm1d(2048)
        self.dropout2 = nn.Dropout(0.5)
        self.dense2 = nn.utils.weight_norm(nn.Linear(2048, 1024))
        
        self.batch_norm3 = nn.BatchNorm1d(1024)
        self.dropout3 = nn.Dropout(0.5)
        self.dense3 = nn.utils.weight_norm(nn.Linear(1024, 206))
    
    def forward(self, x):
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        x = F.leaky_relu(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = F.leaky_relu(self.dense2(x))
        
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x = F.sigmoid(self.dense3(x))
        
        return x

# %%
train_Y4 = train_Y.reset_index(drop=True).append(t)
train_X4 = train_X.reset_index(drop=True)
test_X4 = test_X

all_X4 = train_X4.append(test_X4).drop(columns=['real_drug'])

features_g = [col for col in train_X4.columns if 'g-' in col]
features_c = [col for col in train_X4.columns if 'c-' in col]

all_X4['g_sum'] = all_X4[features_g].sum(axis = 1)
all_X4['g_mean'] = all_X4[features_g].mean(axis = 1)
all_X4['g_std'] = all_X4[features_g].std(axis = 1)
all_X4['g_kurt'] = all_X4[features_g].kurtosis(axis = 1)
all_X4['g_skew'] = all_X4[features_g].skew(axis = 1)
all_X4['c_sum'] = all_X4[features_c].sum(axis = 1)
all_X4['c_mean'] = all_X4[features_c].mean(axis = 1)
all_X4['c_std'] = all_X4[features_c].std(axis = 1)
all_X4['c_kurt'] = all_X4[features_c].kurtosis(axis = 1)
all_X4['c_skew'] = all_X4[features_c].skew(axis = 1)
all_X4['gc_sum'] = all_X4[features_g + features_c].sum(axis = 1)
all_X4['gc_mean'] = all_X4[features_g + features_c].mean(axis = 1)
all_X4['gc_std'] = all_X4[features_g + features_c].std(axis = 1)
all_X4['gc_kurt'] = all_X4[features_g + features_c].kurtosis(axis = 1)
all_X4['gc_skew'] = all_X4[features_g + features_c].skew(axis = 1)

# %%
scaler = GaussRankScaler()
all_X4 = scaler.fit_transform(all_X4)

# %%
pca_transformer = PCA(687)
all_X4 = pca_transformer.fit_transform(all_X4)

# %%
train_X4 = all_X4[:head4]
test_X4 = all_X4[head4:]

# %%
run_CV_for_model(Model4, 4, train_X4, train_Y4, test_X4)
# Out:
# Train fold 1
# Epoch 1/50   -   loss: 0.36586   -   val_loss: 0.06679
# Epoch 2/50   -   loss: 0.04082   -   val_loss: 0.02530
# Epoch 3/50   -   loss: 0.02381   -   val_loss: 0.02034
# Epoch 4/50   -   loss: 0.02053   -   val_loss: 0.01865
# Epoch 5/50   -   loss: 0.01872   -   val_loss: 0.01774
# Epoch 6/50   -   loss: 0.01767   -   val_loss: 0.01708
# Epoch 7/50   -   loss: 0.01690   -   val_loss: 0.01674
# Epoch 8/50   -   loss: 0.01638   -   val_loss: 0.01640
# Epoch 9/50   -   loss: 0.01580   -   val_loss: 0.01624
# Epoch 10/50   -   loss: 0.01534   -   val_loss: 0.01604
# Epoch 11/50   -   loss: 0.01499   -   val_loss: 0.01591
# Epoch 12/50   -   loss: 0.01461   -   val_loss: 0.01576
# Epoch 13/50   -   loss: 0.01425   -   val_loss: 0.01564
# Epoch 14/50   -   loss: 0.01383   -   val_loss: 0.01555
# Epoch 15/50   -   loss: 0.01349   -   val_loss: 0.01543
# Epoch 16/50   -   loss: 0.01312   -   val_loss: 0.01545
# Epoch 17/50   -   loss: 0.01276   -   val_loss: 0.01543
# Epoch 18/50   -   loss: 0.01244   -   val_loss: 0.01540
# Epoch 19/50   -   loss: 0.01212   -   val_loss: 0.01543
# Epoch 20/50   -   loss: 0.01171   -   val_loss: 0.01547
# Epoch 21/50   -   loss: 0.01146   -   val_loss: 0.01547
# Epoch 22/50   -   loss: 0.01106   -   val_loss: 0.01555
# Epoch    22: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 23/50   -   loss: 0.00998   -   val_loss: 0.01546
# Epoch 24/50   -   loss: 0.00972   -   val_loss: 0.01544
# Epoch 25/50   -   loss: 0.00950   -   val_loss: 0.01549
# Epoch 26/50   -   loss: 0.00935   -   val_loss: 0.01546
# Epoch 27/50   -   loss: 0.00913   -   val_loss: 0.01549
# Epoch 28/50   -   loss: 0.00896   -   val_loss: 0.01546
# Epoch 29/50   -   loss: 0.00877   -   val_loss: 0.01544
# Epoch 30/50   -   loss: 0.00860   -   val_loss: 0.01551
# Epoch 31/50   -   loss: 0.00842   -   val_loss: 0.01558
# Epoch 32/50   -   loss: 0.00826   -   val_loss: 0.01556
# Epoch 33/50   -   loss: 0.00799   -   val_loss: 0.01563
# Epoch 34/50   -   loss: 0.00782   -   val_loss: 0.01563
# Epoch 35/50   -   loss: 0.00764   -   val_loss: 0.01567
# Epoch 36/50   -   loss: 0.00743   -   val_loss: 0.01567
# Epoch 37/50   -   loss: 0.00722   -   val_loss: 0.01572
# Epoch 38/50   -   loss: 0.00703   -   val_loss: 0.01583
# Epoch 39/50   -   loss: 0.00681   -   val_loss: 0.01588
# Epoch 40/50   -   loss: 0.00659   -   val_loss: 0.01592
# Epoch 41/50   -   loss: 0.00640   -   val_loss: 0.01598
# Epoch 42/50   -   loss: 0.00616   -   val_loss: 0.01604
# Epoch 43/50   -   loss: 0.00601   -   val_loss: 0.01613
# Epoch 44/50   -   loss: 0.00586   -   val_loss: 0.01619
# Epoch 45/50   -   loss: 0.00566   -   val_loss: 0.01621
# Epoch 46/50   -   loss: 0.00549   -   val_loss: 0.01628
# Epoch 47/50   -   loss: 0.00527   -   val_loss: 0.01643
# Epoch 48/50   -   loss: 0.00511   -   val_loss: 0.01646
# Epoch 49/50   -   loss: 0.00495   -   val_loss: 0.01652
# Epoch 50/50   -   loss: 0.00482   -   val_loss: 0.01664
# Train fold 2
# Epoch 1/50   -   loss: 0.37014   -   val_loss: 0.05948
# Epoch 2/50   -   loss: 0.04045   -   val_loss: 0.02447
# Epoch 3/50   -   loss: 0.02384   -   val_loss: 0.01993
# Epoch 4/50   -   loss: 0.02039   -   val_loss: 0.01854
# Epoch 5/50   -   loss: 0.01875   -   val_loss: 0.01766
# Epoch 6/50   -   loss: 0.01757   -   val_loss: 0.01713
# Epoch 7/50   -   loss: 0.01688   -   val_loss: 0.01676
# Epoch 8/50   -   loss: 0.01629   -   val_loss: 0.01648
# Epoch 9/50   -   loss: 0.01582   -   val_loss: 0.01624
# Epoch 10/50   -   loss: 0.01537   -   val_loss: 0.01608
# Epoch 11/50   -   loss: 0.01504   -   val_loss: 0.01597
# Epoch 12/50   -   loss: 0.01460   -   val_loss: 0.01576
# Epoch 13/50   -   loss: 0.01423   -   val_loss: 0.01573
# Epoch 14/50   -   loss: 0.01381   -   val_loss: 0.01570
# Epoch 15/50   -   loss: 0.01346   -   val_loss: 0.01559
# Epoch 16/50   -   loss: 0.01309   -   val_loss: 0.01550
# Epoch 17/50   -   loss: 0.01274   -   val_loss: 0.01546
# Epoch 18/50   -   loss: 0.01231   -   val_loss: 0.01546
# Epoch 19/50   -   loss: 0.01201   -   val_loss: 0.01557
# Epoch 20/50   -   loss: 0.01163   -   val_loss: 0.01561
# Epoch 21/50   -   loss: 0.01127   -   val_loss: 0.01567
# Epoch 22/50   -   loss: 0.01098   -   val_loss: 0.01569
# Epoch    22: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 23/50   -   loss: 0.00981   -   val_loss: 0.01558
# Epoch 24/50   -   loss: 0.00956   -   val_loss: 0.01558
# Epoch 25/50   -   loss: 0.00937   -   val_loss: 0.01555
# Epoch 26/50   -   loss: 0.00917   -   val_loss: 0.01560
# Epoch 27/50   -   loss: 0.00895   -   val_loss: 0.01557
# Epoch 28/50   -   loss: 0.00881   -   val_loss: 0.01560
# Epoch 29/50   -   loss: 0.00862   -   val_loss: 0.01563
# Epoch 30/50   -   loss: 0.00844   -   val_loss: 0.01568
# Epoch 31/50   -   loss: 0.00820   -   val_loss: 0.01575
# Epoch 32/50   -   loss: 0.00805   -   val_loss: 0.01578
# Epoch 33/50   -   loss: 0.00786   -   val_loss: 0.01576
# Epoch 34/50   -   loss: 0.00766   -   val_loss: 0.01576
# Epoch 35/50   -   loss: 0.00743   -   val_loss: 0.01584
# Epoch 36/50   -   loss: 0.00724   -   val_loss: 0.01590
# Epoch 37/50   -   loss: 0.00703   -   val_loss: 0.01594
# Epoch 38/50   -   loss: 0.00685   -   val_loss: 0.01603
# Epoch 39/50   -   loss: 0.00663   -   val_loss: 0.01607
# Epoch 40/50   -   loss: 0.00636   -   val_loss: 0.01608
# Epoch 41/50   -   loss: 0.00620   -   val_loss: 0.01614
# Epoch 42/50   -   loss: 0.00601   -   val_loss: 0.01621
# Epoch 43/50   -   loss: 0.00580   -   val_loss: 0.01630
# Epoch 44/50   -   loss: 0.00562   -   val_loss: 0.01641
# Epoch 45/50   -   loss: 0.00543   -   val_loss: 0.01643
# Epoch 46/50   -   loss: 0.00528   -   val_loss: 0.01649
# Epoch 47/50   -   loss: 0.00509   -   val_loss: 0.01658
# Epoch 48/50   -   loss: 0.00494   -   val_loss: 0.01660
# Epoch 49/50   -   loss: 0.00480   -   val_loss: 0.01671
# Epoch 50/50   -   loss: 0.00465   -   val_loss: 0.01678
# Train fold 3
# Epoch 1/50   -   loss: 0.36648   -   val_loss: 0.06772
# Epoch 2/50   -   loss: 0.04069   -   val_loss: 0.02576
# Epoch 3/50   -   loss: 0.02385   -   val_loss: 0.02049
# Epoch 4/50   -   loss: 0.02042   -   val_loss: 0.01880
# Epoch 5/50   -   loss: 0.01871   -   val_loss: 0.01773
# Epoch 6/50   -   loss: 0.01767   -   val_loss: 0.01717
# Epoch 7/50   -   loss: 0.01685   -   val_loss: 0.01663
# Epoch 8/50   -   loss: 0.01633   -   val_loss: 0.01640
# Epoch 9/50   -   loss: 0.01587   -   val_loss: 0.01624
# Epoch 10/50   -   loss: 0.01540   -   val_loss: 0.01600
# Epoch 11/50   -   loss: 0.01500   -   val_loss: 0.01580
# Epoch 12/50   -   loss: 0.01456   -   val_loss: 0.01571
# Epoch 13/50   -   loss: 0.01418   -   val_loss: 0.01563
# Epoch 14/50   -   loss: 0.01379   -   val_loss: 0.01554
# Epoch 15/50   -   loss: 0.01342   -   val_loss: 0.01549
# Epoch 16/50   -   loss: 0.01306   -   val_loss: 0.01538
# Epoch 17/50   -   loss: 0.01271   -   val_loss: 0.01536
# Epoch 18/50   -   loss: 0.01244   -   val_loss: 0.01537
# Epoch 19/50   -   loss: 0.01201   -   val_loss: 0.01541
# Epoch 20/50   -   loss: 0.01165   -   val_loss: 0.01533
# Epoch 21/50   -   loss: 0.01135   -   val_loss: 0.01548
# Epoch 22/50   -   loss: 0.01101   -   val_loss: 0.01551
# Epoch 23/50   -   loss: 0.01065   -   val_loss: 0.01554
# Epoch 24/50   -   loss: 0.01034   -   val_loss: 0.01569
# Epoch    24: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 25/50   -   loss: 0.00909   -   val_loss: 0.01560
# Epoch 26/50   -   loss: 0.00882   -   val_loss: 0.01557
# Epoch 27/50   -   loss: 0.00854   -   val_loss: 0.01559
# Epoch 28/50   -   loss: 0.00825   -   val_loss: 0.01561
# Epoch 29/50   -   loss: 0.00801   -   val_loss: 0.01564
# Epoch 30/50   -   loss: 0.00779   -   val_loss: 0.01561
# Epoch 31/50   -   loss: 0.00760   -   val_loss: 0.01566
# Epoch 32/50   -   loss: 0.00736   -   val_loss: 0.01567
# Epoch 33/50   -   loss: 0.00717   -   val_loss: 0.01575
# Epoch 34/50   -   loss: 0.00700   -   val_loss: 0.01576
# Epoch 35/50   -   loss: 0.00674   -   val_loss: 0.01584
# Epoch 36/50   -   loss: 0.00660   -   val_loss: 0.01584
# Epoch 37/50   -   loss: 0.00630   -   val_loss: 0.01592
# Epoch 38/50   -   loss: 0.00614   -   val_loss: 0.01599
# Epoch 39/50   -   loss: 0.00597   -   val_loss: 0.01606
# Epoch 40/50   -   loss: 0.00575   -   val_loss: 0.01615
# Epoch 41/50   -   loss: 0.00560   -   val_loss: 0.01617
# Epoch 42/50   -   loss: 0.00543   -   val_loss: 0.01617
# Epoch 43/50   -   loss: 0.00522   -   val_loss: 0.01625
# Epoch 44/50   -   loss: 0.00508   -   val_loss: 0.01635
# Epoch 45/50   -   loss: 0.00492   -   val_loss: 0.01641
# Epoch 46/50   -   loss: 0.00472   -   val_loss: 0.01645
# Epoch 47/50   -   loss: 0.00457   -   val_loss: 0.01657
# Epoch 48/50   -   loss: 0.00443   -   val_loss: 0.01670
# Epoch 49/50   -   loss: 0.00433   -   val_loss: 0.01666
# Epoch 50/50   -   loss: 0.00422   -   val_loss: 0.01674
# Train fold 4
# Epoch 1/50   -   loss: 0.36759   -   val_loss: 0.05772
# Epoch 2/50   -   loss: 0.04106   -   val_loss: 0.02437
# Epoch 3/50   -   loss: 0.02381   -   val_loss: 0.02005
# Epoch 4/50   -   loss: 0.02023   -   val_loss: 0.01854
# Epoch 5/50   -   loss: 0.01864   -   val_loss: 0.01774
# Epoch 6/50   -   loss: 0.01762   -   val_loss: 0.01728
# Epoch 7/50   -   loss: 0.01687   -   val_loss: 0.01676
# Epoch 8/50   -   loss: 0.01624   -   val_loss: 0.01657
# Epoch 9/50   -   loss: 0.01584   -   val_loss: 0.01641
# Epoch 10/50   -   loss: 0.01545   -   val_loss: 0.01620
# Epoch 11/50   -   loss: 0.01500   -   val_loss: 0.01604
# Epoch 12/50   -   loss: 0.01456   -   val_loss: 0.01594
# Epoch 13/50   -   loss: 0.01422   -   val_loss: 0.01578
# Epoch 14/50   -   loss: 0.01382   -   val_loss: 0.01579
# Epoch 15/50   -   loss: 0.01344   -   val_loss: 0.01566
# Epoch 16/50   -   loss: 0.01303   -   val_loss: 0.01567
# Epoch 17/50   -   loss: 0.01278   -   val_loss: 0.01562
# Epoch 18/50   -   loss: 0.01235   -   val_loss: 0.01562
# Epoch 19/50   -   loss: 0.01200   -   val_loss: 0.01560
# Epoch 20/50   -   loss: 0.01167   -   val_loss: 0.01571
# Epoch 21/50   -   loss: 0.01134   -   val_loss: 0.01576
# Epoch 22/50   -   loss: 0.01105   -   val_loss: 0.01576
# Epoch 23/50   -   loss: 0.01070   -   val_loss: 0.01585
# Epoch    23: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 24/50   -   loss: 0.00953   -   val_loss: 0.01574
# Epoch 25/50   -   loss: 0.00924   -   val_loss: 0.01566
# Epoch 26/50   -   loss: 0.00900   -   val_loss: 0.01566
# Epoch 27/50   -   loss: 0.00881   -   val_loss: 0.01568
# Epoch 28/50   -   loss: 0.00858   -   val_loss: 0.01569
# Epoch 29/50   -   loss: 0.00835   -   val_loss: 0.01576
# Epoch 30/50   -   loss: 0.00822   -   val_loss: 0.01577
# Epoch 31/50   -   loss: 0.00804   -   val_loss: 0.01586
# Epoch 32/50   -   loss: 0.00781   -   val_loss: 0.01585
# Epoch 33/50   -   loss: 0.00760   -   val_loss: 0.01589
# Epoch 34/50   -   loss: 0.00734   -   val_loss: 0.01594
# Epoch 35/50   -   loss: 0.00718   -   val_loss: 0.01596
# Epoch 36/50   -   loss: 0.00697   -   val_loss: 0.01602
# Epoch 37/50   -   loss: 0.00682   -   val_loss: 0.01610
# Epoch 38/50   -   loss: 0.00657   -   val_loss: 0.01612
# Epoch 39/50   -   loss: 0.00640   -   val_loss: 0.01622
# Epoch 40/50   -   loss: 0.00618   -   val_loss: 0.01621
# Epoch 41/50   -   loss: 0.00607   -   val_loss: 0.01630
# Epoch 42/50   -   loss: 0.00580   -   val_loss: 0.01642
# Epoch 43/50   -   loss: 0.00562   -   val_loss: 0.01640
# Epoch 44/50   -   loss: 0.00548   -   val_loss: 0.01649
# Epoch 45/50   -   loss: 0.00531   -   val_loss: 0.01652
# Epoch 46/50   -   loss: 0.00516   -   val_loss: 0.01655
# Epoch 47/50   -   loss: 0.00503   -   val_loss: 0.01664
# Epoch 48/50   -   loss: 0.00477   -   val_loss: 0.01673
# Epoch 49/50   -   loss: 0.00467   -   val_loss: 0.01684
# Epoch 50/50   -   loss: 0.00454   -   val_loss: 0.01692
# Train fold 5
# Epoch 1/50   -   loss: 0.36612   -   val_loss: 0.06270
# Epoch 2/50   -   loss: 0.04105   -   val_loss: 0.02460
# Epoch 3/50   -   loss: 0.02390   -   val_loss: 0.02006
# Epoch 4/50   -   loss: 0.02043   -   val_loss: 0.01849
# Epoch 5/50   -   loss: 0.01879   -   val_loss: 0.01765
# Epoch 6/50   -   loss: 0.01769   -   val_loss: 0.01695
# Epoch 7/50   -   loss: 0.01692   -   val_loss: 0.01671
# Epoch 8/50   -   loss: 0.01637   -   val_loss: 0.01640
# Epoch 9/50   -   loss: 0.01590   -   val_loss: 0.01619
# Epoch 10/50   -   loss: 0.01545   -   val_loss: 0.01602
# Epoch 11/50   -   loss: 0.01502   -   val_loss: 0.01581
# Epoch 12/50   -   loss: 0.01463   -   val_loss: 0.01566
# Epoch 13/50   -   loss: 0.01419   -   val_loss: 0.01561
# Epoch 14/50   -   loss: 0.01377   -   val_loss: 0.01550
# Epoch 15/50   -   loss: 0.01349   -   val_loss: 0.01545
# Epoch 16/50   -   loss: 0.01311   -   val_loss: 0.01538
# Epoch 17/50   -   loss: 0.01273   -   val_loss: 0.01531
# Epoch 18/50   -   loss: 0.01236   -   val_loss: 0.01531
# Epoch 19/50   -   loss: 0.01204   -   val_loss: 0.01532
# Epoch 20/50   -   loss: 0.01165   -   val_loss: 0.01541
# Epoch 21/50   -   loss: 0.01134   -   val_loss: 0.01535
# Epoch    21: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 22/50   -   loss: 0.01030   -   val_loss: 0.01530
# Epoch 23/50   -   loss: 0.01003   -   val_loss: 0.01524
# Epoch 24/50   -   loss: 0.00985   -   val_loss: 0.01524
# Epoch 25/50   -   loss: 0.00969   -   val_loss: 0.01531
# Epoch 26/50   -   loss: 0.00949   -   val_loss: 0.01527
# Epoch 27/50   -   loss: 0.00935   -   val_loss: 0.01527
# Epoch 28/50   -   loss: 0.00918   -   val_loss: 0.01530
# Epoch 29/50   -   loss: 0.00904   -   val_loss: 0.01532
# Epoch 30/50   -   loss: 0.00881   -   val_loss: 0.01533
# Epoch 31/50   -   loss: 0.00868   -   val_loss: 0.01538
# Epoch 32/50   -   loss: 0.00850   -   val_loss: 0.01538
# Epoch 33/50   -   loss: 0.00826   -   val_loss: 0.01541
# Epoch 34/50   -   loss: 0.00807   -   val_loss: 0.01545
# Epoch 35/50   -   loss: 0.00783   -   val_loss: 0.01548
# Epoch 36/50   -   loss: 0.00767   -   val_loss: 0.01550
# Epoch 37/50   -   loss: 0.00746   -   val_loss: 0.01554
# Epoch 38/50   -   loss: 0.00721   -   val_loss: 0.01556
# Epoch 39/50   -   loss: 0.00705   -   val_loss: 0.01564
# Epoch 40/50   -   loss: 0.00683   -   val_loss: 0.01567
# Epoch 41/50   -   loss: 0.00662   -   val_loss: 0.01571
# Epoch 42/50   -   loss: 0.00643   -   val_loss: 0.01572
# Epoch 43/50   -   loss: 0.00620   -   val_loss: 0.01581
# Epoch 44/50   -   loss: 0.00598   -   val_loss: 0.01584
# Epoch 45/50   -   loss: 0.00581   -   val_loss: 0.01593
# Epoch 46/50   -   loss: 0.00564   -   val_loss: 0.01599
# Epoch 47/50   -   loss: 0.00547   -   val_loss: 0.01604
# Epoch 48/50   -   loss: 0.00522   -   val_loss: 0.01611
# Epoch 49/50   -   loss: 0.00515   -   val_loss: 0.01613
# Epoch 50/50   -   loss: 0.00498   -   val_loss: 0.01628
# Train fold 6
# Epoch 1/50   -   loss: 0.36684   -   val_loss: 0.05660
# Epoch 2/50   -   loss: 0.04121   -   val_loss: 0.02429
# Epoch 3/50   -   loss: 0.02397   -   val_loss: 0.01988
# Epoch 4/50   -   loss: 0.02043   -   val_loss: 0.01819
# Epoch 5/50   -   loss: 0.01874   -   val_loss: 0.01719
# Epoch 6/50   -   loss: 0.01770   -   val_loss: 0.01669
# Epoch 7/50   -   loss: 0.01693   -   val_loss: 0.01629
# Epoch 8/50   -   loss: 0.01639   -   val_loss: 0.01611
# Epoch 9/50   -   loss: 0.01587   -   val_loss: 0.01592
# Epoch 10/50   -   loss: 0.01547   -   val_loss: 0.01565
# Epoch 11/50   -   loss: 0.01502   -   val_loss: 0.01552
# Epoch 12/50   -   loss: 0.01468   -   val_loss: 0.01540
# Epoch 13/50   -   loss: 0.01426   -   val_loss: 0.01536
# Epoch 14/50   -   loss: 0.01388   -   val_loss: 0.01520
# Epoch 15/50   -   loss: 0.01351   -   val_loss: 0.01516
# Epoch 16/50   -   loss: 0.01313   -   val_loss: 0.01513
# Epoch 17/50   -   loss: 0.01279   -   val_loss: 0.01511
# Epoch 18/50   -   loss: 0.01241   -   val_loss: 0.01507
# Epoch 19/50   -   loss: 0.01209   -   val_loss: 0.01508
# Epoch 20/50   -   loss: 0.01172   -   val_loss: 0.01507
# Epoch 21/50   -   loss: 0.01134   -   val_loss: 0.01511
# Epoch 22/50   -   loss: 0.01106   -   val_loss: 0.01514
# Epoch 23/50   -   loss: 0.01073   -   val_loss: 0.01532
# Epoch 24/50   -   loss: 0.01045   -   val_loss: 0.01532
# Epoch    24: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 25/50   -   loss: 0.00918   -   val_loss: 0.01521
# Epoch 26/50   -   loss: 0.00884   -   val_loss: 0.01521
# Epoch 27/50   -   loss: 0.00862   -   val_loss: 0.01520
# Epoch 28/50   -   loss: 0.00833   -   val_loss: 0.01525
# Epoch 29/50   -   loss: 0.00815   -   val_loss: 0.01524
# Epoch 30/50   -   loss: 0.00796   -   val_loss: 0.01531
# Epoch 31/50   -   loss: 0.00772   -   val_loss: 0.01532
# Epoch 32/50   -   loss: 0.00750   -   val_loss: 0.01530
# Epoch 33/50   -   loss: 0.00731   -   val_loss: 0.01540
# Epoch 34/50   -   loss: 0.00708   -   val_loss: 0.01543
# Epoch 35/50   -   loss: 0.00684   -   val_loss: 0.01544
# Epoch 36/50   -   loss: 0.00668   -   val_loss: 0.01552
# Epoch 37/50   -   loss: 0.00640   -   val_loss: 0.01558
# Epoch 38/50   -   loss: 0.00629   -   val_loss: 0.01560
# Epoch 39/50   -   loss: 0.00608   -   val_loss: 0.01567
# Epoch 40/50   -   loss: 0.00586   -   val_loss: 0.01573
# Epoch 41/50   -   loss: 0.00566   -   val_loss: 0.01579
# Epoch 42/50   -   loss: 0.00555   -   val_loss: 0.01581
# Epoch 43/50   -   loss: 0.00532   -   val_loss: 0.01594
# Epoch 44/50   -   loss: 0.00515   -   val_loss: 0.01594
# Epoch 45/50   -   loss: 0.00502   -   val_loss: 0.01602
# Epoch 46/50   -   loss: 0.00485   -   val_loss: 0.01608
# Epoch 47/50   -   loss: 0.00468   -   val_loss: 0.01622
# Epoch 48/50   -   loss: 0.00462   -   val_loss: 0.01615
# Epoch 49/50   -   loss: 0.00440   -   val_loss: 0.01626
# Epoch 50/50   -   loss: 0.00429   -   val_loss: 0.01635
# {'train': 0.011721657925061415, 'val': 0.015069309854879975}

# %%
run_eval_for_model(Model4, 4, train_X4[:train_X.shape[0]][train_X['real_drug']], train_Y4[:train_Y.shape[0]][train_X['real_drug']], test_X4)
# Out:
# Overall score is 0.01015

# %%
class Model5(nn.Module):
    def __init__(self, num_columns):
        super(Model5, self).__init__()
        self.batch_norm1 = nn.BatchNorm1d(num_columns)
        self.dropout1 = nn.Dropout(0.2)
        self.dense1 = nn.utils.weight_norm(nn.Linear(num_columns, 2048))
        
        self.batch_norm2 = nn.BatchNorm1d(2048)
        self.dropout2 = nn.Dropout(0.5)
        self.dense2 = nn.utils.weight_norm(nn.Linear(2048, 1024))
        
        self.batch_norm3 = nn.BatchNorm1d(1024)
        self.dropout3 = nn.Dropout(0.5)
        self.dense3 = nn.utils.weight_norm(nn.Linear(1024, 206))
    
    def forward(self, x):
        x = self.batch_norm1(x)
        x = self.dropout1(x)
        x = F.leaky_relu(self.dense1(x))
        
        x = self.batch_norm2(x)
        x = self.dropout2(x)
        x = F.leaky_relu(self.dense2(x))
        
        x = self.batch_norm3(x)
        x = self.dropout3(x)
        x = F.sigmoid(self.dense3(x))
        
        return x

# %%
train_X5 = train_X4
test_X5 = test_X4
train_Y5 = train_Y4.copy()
alpha_smoothing = 0.001
train_Y5 = (1 - alpha_smoothing) * train_Y5 + alpha_smoothing * train_Y5.mean(axis=1)[:, None]

# %%
run_CV_for_model(Model5, 5, train_X5, train_Y5, test_X5)
# Out:
# Train fold 1
# Epoch 1/50   -   loss: 0.36745   -   val_loss: 0.06441
# Epoch 2/50   -   loss: 0.04121   -   val_loss: 0.02531
# Epoch 3/50   -   loss: 0.02399   -   val_loss: 0.02044
# Epoch 4/50   -   loss: 0.02040   -   val_loss: 0.01866
# Epoch 5/50   -   loss: 0.01873   -   val_loss: 0.01777
# Epoch 6/50   -   loss: 0.01766   -   val_loss: 0.01715
# Epoch 7/50   -   loss: 0.01692   -   val_loss: 0.01666
# Epoch 8/50   -   loss: 0.01630   -   val_loss: 0.01642
# Epoch 9/50   -   loss: 0.01579   -   val_loss: 0.01620
# Epoch 10/50   -   loss: 0.01541   -   val_loss: 0.01606
# Epoch 11/50   -   loss: 0.01501   -   val_loss: 0.01587
# Epoch 12/50   -   loss: 0.01454   -   val_loss: 0.01574
# Epoch 13/50   -   loss: 0.01419   -   val_loss: 0.01561
# Epoch 14/50   -   loss: 0.01385   -   val_loss: 0.01560
# Epoch 15/50   -   loss: 0.01344   -   val_loss: 0.01550
# Epoch 16/50   -   loss: 0.01307   -   val_loss: 0.01544
# Epoch 17/50   -   loss: 0.01271   -   val_loss: 0.01547
# Epoch 18/50   -   loss: 0.01239   -   val_loss: 0.01552
# Epoch 19/50   -   loss: 0.01211   -   val_loss: 0.01547
# Epoch 20/50   -   loss: 0.01170   -   val_loss: 0.01544
# Epoch 21/50   -   loss: 0.01131   -   val_loss: 0.01545
# Epoch 22/50   -   loss: 0.01104   -   val_loss: 0.01551
# Epoch 23/50   -   loss: 0.01075   -   val_loss: 0.01550
# Epoch 24/50   -   loss: 0.01044   -   val_loss: 0.01567
# Epoch    24: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 25/50   -   loss: 0.00918   -   val_loss: 0.01560
# Epoch 26/50   -   loss: 0.00888   -   val_loss: 0.01558
# Epoch 27/50   -   loss: 0.00860   -   val_loss: 0.01556
# Epoch 28/50   -   loss: 0.00839   -   val_loss: 0.01557
# Epoch 29/50   -   loss: 0.00820   -   val_loss: 0.01561
# Epoch 30/50   -   loss: 0.00795   -   val_loss: 0.01564
# Epoch 31/50   -   loss: 0.00771   -   val_loss: 0.01563
# Epoch 32/50   -   loss: 0.00753   -   val_loss: 0.01563
# Epoch 33/50   -   loss: 0.00730   -   val_loss: 0.01567
# Epoch 34/50   -   loss: 0.00714   -   val_loss: 0.01571
# Epoch 35/50   -   loss: 0.00690   -   val_loss: 0.01577
# Epoch 36/50   -   loss: 0.00667   -   val_loss: 0.01578
# Epoch 37/50   -   loss: 0.00652   -   val_loss: 0.01593
# Epoch 38/50   -   loss: 0.00633   -   val_loss: 0.01593
# Epoch 39/50   -   loss: 0.00609   -   val_loss: 0.01596
# Epoch 40/50   -   loss: 0.00592   -   val_loss: 0.01602
# Epoch 41/50   -   loss: 0.00580   -   val_loss: 0.01608
# Epoch 42/50   -   loss: 0.00559   -   val_loss: 0.01611
# Epoch 43/50   -   loss: 0.00541   -   val_loss: 0.01622
# Epoch 44/50   -   loss: 0.00520   -   val_loss: 0.01627
# Epoch 45/50   -   loss: 0.00502   -   val_loss: 0.01634
# Epoch 46/50   -   loss: 0.00490   -   val_loss: 0.01638
# Epoch 47/50   -   loss: 0.00476   -   val_loss: 0.01649
# Epoch 48/50   -   loss: 0.00461   -   val_loss: 0.01653
# Epoch 49/50   -   loss: 0.00449   -   val_loss: 0.01662
# Epoch 50/50   -   loss: 0.00432   -   val_loss: 0.01668
# Train fold 2
# Epoch 1/50   -   loss: 0.36727   -   val_loss: 0.06670
# Epoch 2/50   -   loss: 0.04087   -   val_loss: 0.02510
# Epoch 3/50   -   loss: 0.02391   -   val_loss: 0.02060
# Epoch 4/50   -   loss: 0.02047   -   val_loss: 0.01874
# Epoch 5/50   -   loss: 0.01878   -   val_loss: 0.01786
# Epoch 6/50   -   loss: 0.01764   -   val_loss: 0.01731
# Epoch 7/50   -   loss: 0.01691   -   val_loss: 0.01690
# Epoch 8/50   -   loss: 0.01632   -   val_loss: 0.01668
# Epoch 9/50   -   loss: 0.01580   -   val_loss: 0.01638
# Epoch 10/50   -   loss: 0.01536   -   val_loss: 0.01624
# Epoch 11/50   -   loss: 0.01495   -   val_loss: 0.01604
# Epoch 12/50   -   loss: 0.01455   -   val_loss: 0.01594
# Epoch 13/50   -   loss: 0.01420   -   val_loss: 0.01587
# Epoch 14/50   -   loss: 0.01384   -   val_loss: 0.01578
# Epoch 15/50   -   loss: 0.01346   -   val_loss: 0.01568
# Epoch 16/50   -   loss: 0.01312   -   val_loss: 0.01562
# Epoch 17/50   -   loss: 0.01277   -   val_loss: 0.01563
# Epoch 18/50   -   loss: 0.01240   -   val_loss: 0.01568
# Epoch 19/50   -   loss: 0.01199   -   val_loss: 0.01572
# Epoch 20/50   -   loss: 0.01173   -   val_loss: 0.01572
# Epoch    20: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 21/50   -   loss: 0.01076   -   val_loss: 0.01561
# Epoch 22/50   -   loss: 0.01053   -   val_loss: 0.01555
# Epoch 23/50   -   loss: 0.01031   -   val_loss: 0.01554
# Epoch 24/50   -   loss: 0.01018   -   val_loss: 0.01555
# Epoch 25/50   -   loss: 0.01002   -   val_loss: 0.01556
# Epoch 26/50   -   loss: 0.00987   -   val_loss: 0.01558
# Epoch 27/50   -   loss: 0.00973   -   val_loss: 0.01556
# Epoch 28/50   -   loss: 0.00958   -   val_loss: 0.01556
# Epoch 29/50   -   loss: 0.00937   -   val_loss: 0.01564
# Epoch 30/50   -   loss: 0.00927   -   val_loss: 0.01566
# Epoch 31/50   -   loss: 0.00908   -   val_loss: 0.01565
# Epoch 32/50   -   loss: 0.00891   -   val_loss: 0.01569
# Epoch 33/50   -   loss: 0.00875   -   val_loss: 0.01568
# Epoch 34/50   -   loss: 0.00855   -   val_loss: 0.01571
# Epoch 35/50   -   loss: 0.00837   -   val_loss: 0.01575
# Epoch 36/50   -   loss: 0.00815   -   val_loss: 0.01574
# Epoch 37/50   -   loss: 0.00797   -   val_loss: 0.01582
# Epoch 38/50   -   loss: 0.00777   -   val_loss: 0.01579
# Epoch 39/50   -   loss: 0.00755   -   val_loss: 0.01586
# Epoch 40/50   -   loss: 0.00735   -   val_loss: 0.01591
# Epoch 41/50   -   loss: 0.00712   -   val_loss: 0.01594
# Epoch 42/50   -   loss: 0.00695   -   val_loss: 0.01601
# Epoch 43/50   -   loss: 0.00671   -   val_loss: 0.01610
# Epoch 44/50   -   loss: 0.00646   -   val_loss: 0.01615
# Epoch 45/50   -   loss: 0.00628   -   val_loss: 0.01619
# Epoch 46/50   -   loss: 0.00608   -   val_loss: 0.01628
# Epoch 47/50   -   loss: 0.00589   -   val_loss: 0.01631
# Epoch 48/50   -   loss: 0.00576   -   val_loss: 0.01638
# Epoch 49/50   -   loss: 0.00552   -   val_loss: 0.01645
# Epoch 50/50   -   loss: 0.00532   -   val_loss: 0.01652
# Train fold 3
# Epoch 1/50   -   loss: 0.36871   -   val_loss: 0.06291
# Epoch 2/50   -   loss: 0.04137   -   val_loss: 0.02383
# Epoch 3/50   -   loss: 0.02394   -   val_loss: 0.01962
# Epoch 4/50   -   loss: 0.02047   -   val_loss: 0.01822
# Epoch 5/50   -   loss: 0.01892   -   val_loss: 0.01739
# Epoch 6/50   -   loss: 0.01776   -   val_loss: 0.01684
# Epoch 7/50   -   loss: 0.01704   -   val_loss: 0.01657
# Epoch 8/50   -   loss: 0.01637   -   val_loss: 0.01626
# Epoch 9/50   -   loss: 0.01592   -   val_loss: 0.01607
# Epoch 10/50   -   loss: 0.01545   -   val_loss: 0.01586
# Epoch 11/50   -   loss: 0.01500   -   val_loss: 0.01572
# Epoch 12/50   -   loss: 0.01469   -   val_loss: 0.01555
# Epoch 13/50   -   loss: 0.01432   -   val_loss: 0.01549
# Epoch 14/50   -   loss: 0.01389   -   val_loss: 0.01545
# Epoch 15/50   -   loss: 0.01352   -   val_loss: 0.01531
# Epoch 16/50   -   loss: 0.01316   -   val_loss: 0.01531
# Epoch 17/50   -   loss: 0.01277   -   val_loss: 0.01532
# Epoch 18/50   -   loss: 0.01250   -   val_loss: 0.01531
# Epoch 19/50   -   loss: 0.01209   -   val_loss: 0.01532
# Epoch 20/50   -   loss: 0.01179   -   val_loss: 0.01535
# Epoch 21/50   -   loss: 0.01146   -   val_loss: 0.01537
# Epoch 22/50   -   loss: 0.01116   -   val_loss: 0.01541
# Epoch    22: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 23/50   -   loss: 0.01000   -   val_loss: 0.01536
# Epoch 24/50   -   loss: 0.00971   -   val_loss: 0.01532
# Epoch 25/50   -   loss: 0.00956   -   val_loss: 0.01534
# Epoch 26/50   -   loss: 0.00934   -   val_loss: 0.01532
# Epoch 27/50   -   loss: 0.00920   -   val_loss: 0.01535
# Epoch 28/50   -   loss: 0.00901   -   val_loss: 0.01534
# Epoch 29/50   -   loss: 0.00880   -   val_loss: 0.01537
# Epoch 30/50   -   loss: 0.00860   -   val_loss: 0.01541
# Epoch 31/50   -   loss: 0.00839   -   val_loss: 0.01543
# Epoch 32/50   -   loss: 0.00824   -   val_loss: 0.01545
# Epoch 33/50   -   loss: 0.00802   -   val_loss: 0.01549
# Epoch 34/50   -   loss: 0.00782   -   val_loss: 0.01551
# Epoch 35/50   -   loss: 0.00767   -   val_loss: 0.01553
# Epoch 36/50   -   loss: 0.00744   -   val_loss: 0.01559
# Epoch 37/50   -   loss: 0.00723   -   val_loss: 0.01564
# Epoch 38/50   -   loss: 0.00705   -   val_loss: 0.01568
# Epoch 39/50   -   loss: 0.00683   -   val_loss: 0.01569
# Epoch 40/50   -   loss: 0.00655   -   val_loss: 0.01584
# Epoch 41/50   -   loss: 0.00641   -   val_loss: 0.01589
# Epoch 42/50   -   loss: 0.00621   -   val_loss: 0.01586
# Epoch 43/50   -   loss: 0.00606   -   val_loss: 0.01595
# Epoch 44/50   -   loss: 0.00581   -   val_loss: 0.01597
# Epoch 45/50   -   loss: 0.00563   -   val_loss: 0.01613
# Epoch 46/50   -   loss: 0.00553   -   val_loss: 0.01613
# Epoch 47/50   -   loss: 0.00533   -   val_loss: 0.01620
# Epoch 48/50   -   loss: 0.00518   -   val_loss: 0.01626
# Epoch 49/50   -   loss: 0.00500   -   val_loss: 0.01634
# Epoch 50/50   -   loss: 0.00486   -   val_loss: 0.01639
# Train fold 4
# Epoch 1/50   -   loss: 0.36519   -   val_loss: 0.05698
# Epoch 2/50   -   loss: 0.04112   -   val_loss: 0.02351
# Epoch 3/50   -   loss: 0.02427   -   val_loss: 0.01967
# Epoch 4/50   -   loss: 0.02041   -   val_loss: 0.01830
# Epoch 5/50   -   loss: 0.01876   -   val_loss: 0.01756
# Epoch 6/50   -   loss: 0.01766   -   val_loss: 0.01712
# Epoch 7/50   -   loss: 0.01689   -   val_loss: 0.01675
# Epoch 8/50   -   loss: 0.01634   -   val_loss: 0.01650
# Epoch 9/50   -   loss: 0.01586   -   val_loss: 0.01627
# Epoch 10/50   -   loss: 0.01544   -   val_loss: 0.01616
# Epoch 11/50   -   loss: 0.01502   -   val_loss: 0.01600
# Epoch 12/50   -   loss: 0.01466   -   val_loss: 0.01585
# Epoch 13/50   -   loss: 0.01421   -   val_loss: 0.01574
# Epoch 14/50   -   loss: 0.01385   -   val_loss: 0.01567
# Epoch 15/50   -   loss: 0.01347   -   val_loss: 0.01570
# Epoch 16/50   -   loss: 0.01310   -   val_loss: 0.01559
# Epoch 17/50   -   loss: 0.01274   -   val_loss: 0.01560
# Epoch 18/50   -   loss: 0.01237   -   val_loss: 0.01561
# Epoch 19/50   -   loss: 0.01205   -   val_loss: 0.01565
# Epoch 20/50   -   loss: 0.01168   -   val_loss: 0.01557
# Epoch 21/50   -   loss: 0.01136   -   val_loss: 0.01573
# Epoch 22/50   -   loss: 0.01105   -   val_loss: 0.01563
# Epoch 23/50   -   loss: 0.01076   -   val_loss: 0.01565
# Epoch 24/50   -   loss: 0.01039   -   val_loss: 0.01579
# Epoch    24: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 25/50   -   loss: 0.00923   -   val_loss: 0.01570
# Epoch 26/50   -   loss: 0.00890   -   val_loss: 0.01571
# Epoch 27/50   -   loss: 0.00863   -   val_loss: 0.01571
# Epoch 28/50   -   loss: 0.00843   -   val_loss: 0.01571
# Epoch 29/50   -   loss: 0.00821   -   val_loss: 0.01570
# Epoch 30/50   -   loss: 0.00794   -   val_loss: 0.01579
# Epoch 31/50   -   loss: 0.00776   -   val_loss: 0.01583
# Epoch 32/50   -   loss: 0.00752   -   val_loss: 0.01584
# Epoch 33/50   -   loss: 0.00731   -   val_loss: 0.01589
# Epoch 34/50   -   loss: 0.00712   -   val_loss: 0.01593
# Epoch 35/50   -   loss: 0.00688   -   val_loss: 0.01598
# Epoch 36/50   -   loss: 0.00668   -   val_loss: 0.01602
# Epoch 37/50   -   loss: 0.00648   -   val_loss: 0.01604
# Epoch 38/50   -   loss: 0.00632   -   val_loss: 0.01614
# Epoch 39/50   -   loss: 0.00609   -   val_loss: 0.01615
# Epoch 40/50   -   loss: 0.00590   -   val_loss: 0.01623
# Epoch 41/50   -   loss: 0.00572   -   val_loss: 0.01626
# Epoch 42/50   -   loss: 0.00559   -   val_loss: 0.01637
# Epoch 43/50   -   loss: 0.00538   -   val_loss: 0.01647
# Epoch 44/50   -   loss: 0.00522   -   val_loss: 0.01655
# Epoch 45/50   -   loss: 0.00503   -   val_loss: 0.01660
# Epoch 46/50   -   loss: 0.00489   -   val_loss: 0.01663
# Epoch 47/50   -   loss: 0.00476   -   val_loss: 0.01668
# Epoch 48/50   -   loss: 0.00461   -   val_loss: 0.01676
# Epoch 49/50   -   loss: 0.00446   -   val_loss: 0.01681
# Epoch 50/50   -   loss: 0.00430   -   val_loss: 0.01684
# Train fold 5
# Epoch 1/50   -   loss: 0.36618   -   val_loss: 0.06228
# Epoch 2/50   -   loss: 0.04078   -   val_loss: 0.02470
# Epoch 3/50   -   loss: 0.02402   -   val_loss: 0.02017
# Epoch 4/50   -   loss: 0.02056   -   val_loss: 0.01847
# Epoch 5/50   -   loss: 0.01889   -   val_loss: 0.01748
# Epoch 6/50   -   loss: 0.01770   -   val_loss: 0.01705
# Epoch 7/50   -   loss: 0.01694   -   val_loss: 0.01653
# Epoch 8/50   -   loss: 0.01645   -   val_loss: 0.01630
# Epoch 9/50   -   loss: 0.01585   -   val_loss: 0.01613
# Epoch 10/50   -   loss: 0.01547   -   val_loss: 0.01598
# Epoch 11/50   -   loss: 0.01506   -   val_loss: 0.01578
# Epoch 12/50   -   loss: 0.01461   -   val_loss: 0.01561
# Epoch 13/50   -   loss: 0.01422   -   val_loss: 0.01553
# Epoch 14/50   -   loss: 0.01383   -   val_loss: 0.01555
# Epoch 15/50   -   loss: 0.01346   -   val_loss: 0.01540
# Epoch 16/50   -   loss: 0.01311   -   val_loss: 0.01540
# Epoch 17/50   -   loss: 0.01272   -   val_loss: 0.01534
# Epoch 18/50   -   loss: 0.01241   -   val_loss: 0.01536
# Epoch 19/50   -   loss: 0.01201   -   val_loss: 0.01536
# Epoch 20/50   -   loss: 0.01165   -   val_loss: 0.01544
# Epoch 21/50   -   loss: 0.01136   -   val_loss: 0.01536
# Epoch    21: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 22/50   -   loss: 0.01029   -   val_loss: 0.01526
# Epoch 23/50   -   loss: 0.01005   -   val_loss: 0.01525
# Epoch 24/50   -   loss: 0.00986   -   val_loss: 0.01533
# Epoch 25/50   -   loss: 0.00963   -   val_loss: 0.01526
# Epoch 26/50   -   loss: 0.00952   -   val_loss: 0.01531
# Epoch 27/50   -   loss: 0.00935   -   val_loss: 0.01529
# Epoch 28/50   -   loss: 0.00921   -   val_loss: 0.01535
# Epoch 29/50   -   loss: 0.00899   -   val_loss: 0.01533
# Epoch 30/50   -   loss: 0.00878   -   val_loss: 0.01538
# Epoch 31/50   -   loss: 0.00863   -   val_loss: 0.01540
# Epoch 32/50   -   loss: 0.00842   -   val_loss: 0.01547
# Epoch 33/50   -   loss: 0.00821   -   val_loss: 0.01547
# Epoch 34/50   -   loss: 0.00801   -   val_loss: 0.01551
# Epoch 35/50   -   loss: 0.00785   -   val_loss: 0.01553
# Epoch 36/50   -   loss: 0.00766   -   val_loss: 0.01559
# Epoch 37/50   -   loss: 0.00742   -   val_loss: 0.01564
# Epoch 38/50   -   loss: 0.00723   -   val_loss: 0.01567
# Epoch 39/50   -   loss: 0.00705   -   val_loss: 0.01567
# Epoch 40/50   -   loss: 0.00679   -   val_loss: 0.01569
# Epoch 41/50   -   loss: 0.00658   -   val_loss: 0.01584
# Epoch 42/50   -   loss: 0.00642   -   val_loss: 0.01586
# Epoch 43/50   -   loss: 0.00625   -   val_loss: 0.01585
# Epoch 44/50   -   loss: 0.00603   -   val_loss: 0.01598
# Epoch 45/50   -   loss: 0.00582   -   val_loss: 0.01604
# Epoch 46/50   -   loss: 0.00566   -   val_loss: 0.01609
# Epoch 47/50   -   loss: 0.00542   -   val_loss: 0.01615
# Epoch 48/50   -   loss: 0.00534   -   val_loss: 0.01615
# Epoch 49/50   -   loss: 0.00507   -   val_loss: 0.01623
# Epoch 50/50   -   loss: 0.00501   -   val_loss: 0.01634
# Train fold 6
# Epoch 1/50   -   loss: 0.36915   -   val_loss: 0.06477
# Epoch 2/50   -   loss: 0.04061   -   val_loss: 0.02580
# Epoch 3/50   -   loss: 0.02393   -   val_loss: 0.02071
# Epoch 4/50   -   loss: 0.02055   -   val_loss: 0.01878
# Epoch 5/50   -   loss: 0.01868   -   val_loss: 0.01791
# Epoch 6/50   -   loss: 0.01769   -   val_loss: 0.01723
# Epoch 7/50   -   loss: 0.01687   -   val_loss: 0.01689
# Epoch 8/50   -   loss: 0.01631   -   val_loss: 0.01666
# Epoch 9/50   -   loss: 0.01582   -   val_loss: 0.01650
# Epoch 10/50   -   loss: 0.01538   -   val_loss: 0.01622
# Epoch 11/50   -   loss: 0.01492   -   val_loss: 0.01600
# Epoch 12/50   -   loss: 0.01455   -   val_loss: 0.01592
# Epoch 13/50   -   loss: 0.01416   -   val_loss: 0.01582
# Epoch 14/50   -   loss: 0.01382   -   val_loss: 0.01576
# Epoch 15/50   -   loss: 0.01345   -   val_loss: 0.01566
# Epoch 16/50   -   loss: 0.01309   -   val_loss: 0.01559
# Epoch 17/50   -   loss: 0.01264   -   val_loss: 0.01552
# Epoch 18/50   -   loss: 0.01235   -   val_loss: 0.01557
# Epoch 19/50   -   loss: 0.01196   -   val_loss: 0.01553
# Epoch 20/50   -   loss: 0.01172   -   val_loss: 0.01560
# Epoch 21/50   -   loss: 0.01135   -   val_loss: 0.01561
# Epoch    21: reducing learning rate of group 0 to 1.0000e-04.
# Epoch 22/50   -   loss: 0.01029   -   val_loss: 0.01556
# Epoch 23/50   -   loss: 0.01001   -   val_loss: 0.01552
# Epoch 24/50   -   loss: 0.00981   -   val_loss: 0.01552
# Epoch 25/50   -   loss: 0.00966   -   val_loss: 0.01555
# Epoch 26/50   -   loss: 0.00948   -   val_loss: 0.01554
# Epoch 27/50   -   loss: 0.00930   -   val_loss: 0.01558
# Epoch 28/50   -   loss: 0.00917   -   val_loss: 0.01560
# Epoch 29/50   -   loss: 0.00896   -   val_loss: 0.01560
# Epoch 30/50   -   loss: 0.00882   -   val_loss: 0.01566
# Epoch 31/50   -   loss: 0.00867   -   val_loss: 0.01563
# Epoch 32/50   -   loss: 0.00838   -   val_loss: 0.01566
# Epoch 33/50   -   loss: 0.00822   -   val_loss: 0.01569
# Epoch 34/50   -   loss: 0.00804   -   val_loss: 0.01574
# Epoch 35/50   -   loss: 0.00785   -   val_loss: 0.01573
# Epoch 36/50   -   loss: 0.00767   -   val_loss: 0.01577
# Epoch 37/50   -   loss: 0.00745   -   val_loss: 0.01583
# Epoch 38/50   -   loss: 0.00720   -   val_loss: 0.01586
# Epoch 39/50   -   loss: 0.00704   -   val_loss: 0.01588
# Epoch 40/50   -   loss: 0.00681   -   val_loss: 0.01593
# Epoch 41/50   -   loss: 0.00665   -   val_loss: 0.01599
# Epoch 42/50   -   loss: 0.00640   -   val_loss: 0.01601
# Epoch 43/50   -   loss: 0.00617   -   val_loss: 0.01612
# Epoch 44/50   -   loss: 0.00601   -   val_loss: 0.01613
# Epoch 45/50   -   loss: 0.00582   -   val_loss: 0.01616
# Epoch 46/50   -   loss: 0.00561   -   val_loss: 0.01629
# Epoch 47/50   -   loss: 0.00547   -   val_loss: 0.01630
# Epoch 48/50   -   loss: 0.00524   -   val_loss: 0.01636
# Epoch 49/50   -   loss: 0.00507   -   val_loss: 0.01648
# Epoch 50/50   -   loss: 0.00500   -   val_loss: 0.01648
# {'train': 0.009807500911617204, 'val': 0.0155167521443218}

# %%
run_eval_for_model(Model5, 5, train_X5[:train_X.shape[0]][train_X['real_drug']], train_Y5[:train_Y.shape[0]][train_X['real_drug']], test_X5)
# Out:
# Overall score is 0.00972
